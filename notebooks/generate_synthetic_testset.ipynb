# %% [markdown]
# # Generating Syntethic Test-sets based on SSE lecture slides
#
# ## General Setup

# %%
import os
import dotenv
dotenv.load_dotenv()
from typing import List, Tuple, Any
import typing as t
import asyncio

# For PDF extraction
from langchain_community.document_loaders import PyPDFLoader

# Ragas components
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from ragas.testset.graph import KnowledgeGraph, Node, NodeType
from ragas.testset.transforms import (
    apply_transforms,
    HeadlinesExtractor,
    HeadlineSplitter,
    KeyphrasesExtractor,
    OverlapScoreBuilder
)
from ragas.testset.persona import Persona
from ragas.testset.synthesizers.single_hop.specific import SingleHopSpecificQuerySynthesizer
from ragas.testset import TestsetGenerator

from ragas.testset.synthesizers.multi_hop.base import (
    MultiHopQuerySynthesizer,
    MultiHopScenario,
)
from ragas.testset.synthesizers.prompts import (
    ThemesPersonasInput,
    ThemesPersonasMatchingPrompt,
)

# LLM and embeddings
from langchain_groq import ChatGroq
from langchain_openai import OpenAIEmbeddings
from dataclasses import dataclass
from pprint import pprint

import pandas as pd

# %%
def load_pdf_documents(pdf_dir: str) -> List[Any]:
    """
    Load all PDF files from a directory and convert them to documents.
    """
    documents = []
    for filename in os.listdir(pdf_dir):
        if filename.endswith(".pdf"):
            file_path = os.path.join(pdf_dir, filename)
            print(f"Loading {filename}...")
            try:
                loader = PyPDFLoader(file_path)
                # Split by page to manage large files better
                docs = loader.load_and_split()
                documents.extend(docs)
                print(f"  Added {len(docs)} pages from {filename}")
            except Exception as e:
                print(f"  Error loading {filename}: {e}")
    
    return documents


def create_sustainable_se_personas() -> List[Persona]:
    """
    Create personas relevant to sustainable software engineering.
    """
    persona_prepared_student = Persona(
        name="Prepared Computer Science Student",
        role_description="A university student learning about sustainable software engineering. Has a good general overview of topics, but intrested in the finer technical details."
    )

    persona_lazy_student = Persona(
        name="Lazy Computer Science Student",
        role_description="A computer science student that barely knows the content, hasn't attended lectures, but is making a start with his studies. In addition to less tecnical questions, is also interested in organisational matters."
    )

    persona_curious_developer = Persona(
        name="Professional Developer",
        role_description="A software developer in the industry looking to learn about green software practices to apply in their projects and convince management of their importance."
    )

    return [persona_prepared_student, persona_lazy_student, persona_curious_developer]


def prepare_knowledge_graph(pdf_dir: str) -> Tuple[KnowledgeGraph, LangchainLLMWrapper, LangchainEmbeddingsWrapper]:
        """
        Prepare the knowledge graph and models from PDF documents.
        
        Args:
            pdf_dir: Directory containing PDF files to process
            
        Returns:
            Tuple containing:
            - The prepared knowledge graph
            - The LLM wrapper
            - The embeddings wrapper
        """
        # Step 1: Load PDF documents
        print("Loading PDF documents...")
        documents = load_pdf_documents(pdf_dir)
        print(f"Loaded {len(documents)} document chunks.")
        
        # Step 2: Set up Groq LLM and embedding models
        print("Setting up LLM and embedding models...")
        generator_llm = LangchainLLMWrapper(
            ChatGroq(model="deepseek-r1-distill-qwen-32b", temperature=0.2, max_tokens=4096)
        )
        # Still using OpenAI for embeddings as Groq doesn't have embedding models
        generator_embeddings = LangchainEmbeddingsWrapper(OpenAIEmbeddings(model="text-embedding-3-small"))
        
        # Step 3: Create knowledge graph
        print("Creating knowledge graph...")
        kg = KnowledgeGraph()
        
        for doc in documents:
            kg.nodes.append(
                Node(
                    type=NodeType.DOCUMENT,
                    properties={"page_content": doc.page_content, "document_metadata": doc.metadata}
                )
            )
        
        print(f"Created initial knowledge graph with {len(kg.nodes)} nodes.")
        return kg, generator_llm, generator_embeddings

# %% [markdown]
# ## Setup for single-hop test-set generation

# %%
pdf_dir = "data/sse_lectures"

"""
Generate a testset for sustainable software engineering using PDF lecture slides.
"""
# Steps 1 - 3: Prepare knowledge graph and models
kg, generator_llm, generator_embeddings = prepare_knowledge_graph(pdf_dir)

# Step 4: Apply transforms
print("Applying transforms to enhance knowledge graph...")
transforms = [
    HeadlinesExtractor(llm=generator_llm, max_num=10),
    HeadlineSplitter(max_tokens=1000),
    KeyphrasesExtractor(llm=generator_llm, property_name="keyphrases", max_num=10)
]

apply_transforms(kg, transforms=transforms)
print(f"Knowledge graph now has {len(kg.nodes)} nodes after transforms.")

# Step 5: Configure personas
personas = create_sustainable_se_personas()

# Step 6: Set up query synthesizers
query_distribution = [
    (
        SingleHopSpecificQuerySynthesizer(llm=generator_llm, property_name="headlines"),
        0.5,
    ),
    (
        SingleHopSpecificQuerySynthesizer(llm=generator_llm, property_name="keyphrases"),
        0.5,
    ),
]
# Out:
# Ignoring wrong pointing object 64 0 (offset 0)
# Ignoring wrong pointing object 70 0 (offset 0)
# Ignoring wrong pointing object 192 0 (offset 0)
# Ignoring wrong pointing object 319 0 (offset 0)
# Ignoring wrong pointing object 320 0 (offset 0)
# Ignoring wrong pointing object 90 0 (offset 0)
# Loading PDF documents...
# Loading 01_intro.pdf...
#   Added 42 pages from 01_intro.pdf
# Loading 02_lab_measuring_energy.pdf...
# Ignoring wrong pointing object 206 0 (offset 0)
# Ignoring wrong pointing object 207 0 (offset 0)
# Ignoring wrong pointing object 32 0 (offset 0)
# Ignoring wrong pointing object 66 0 (offset 0)
# Ignoring wrong pointing object 123 0 (offset 0)
#   Added 27 pages from 02_lab_measuring_energy.pdf
# Loading 03_scientific_guide.pdf...
# Ignoring wrong pointing object 46 0 (offset 0)
# Ignoring wrong pointing object 72 0 (offset 0)
# Ignoring wrong pointing object 142 0 (offset 0)
# Ignoring wrong pointing object 242 0 (offset 0)
# Ignoring wrong pointing object 243 0 (offset 0)
#   Added 39 pages from 03_scientific_guide.pdf
# Loading 05_metrics.pdf...
# Ignoring wrong pointing object 174 0 (offset 0)
# Ignoring wrong pointing object 234 0 (offset 0)
# Ignoring wrong pointing object 243 0 (offset 0)
# Ignoring wrong pointing object 355 0 (offset 0)
# Ignoring wrong pointing object 386 0 (offset 0)
# Ignoring wrong pointing object 388 0 (offset 0)
# Ignoring wrong pointing object 398 0 (offset 0)
# Ignoring wrong pointing object 400 0 (offset 0)
# Ignoring wrong pointing object 407 0 (offset 0)
# Ignoring wrong pointing object 409 0 (offset 0)
# Ignoring wrong pointing object 415 0 (offset 0)
# Ignoring wrong pointing object 417 0 (offset 0)
# Ignoring wrong pointing object 423 0 (offset 0)
# Ignoring wrong pointing object 425 0 (offset 0)
# Ignoring wrong pointing object 431 0 (offset 0)
# Ignoring wrong pointing object 433 0 (offset 0)
# Ignoring wrong pointing object 489 0 (offset 0)
# Ignoring wrong pointing object 491 0 (offset 0)
# Ignoring wrong pointing object 493 0 (offset 0)
# Ignoring wrong pointing object 495 0 (offset 0)
# Ignoring wrong pointing object 497 0 (offset 0)
# Ignoring wrong pointing object 499 0 (offset 0)
# Ignoring wrong pointing object 501 0 (offset 0)
# Ignoring wrong pointing object 503 0 (offset 0)
# Ignoring wrong pointing object 505 0 (offset 0)
# Ignoring wrong pointing object 507 0 (offset 0)
# Ignoring wrong pointing object 509 0 (offset 0)
# Ignoring wrong pointing object 511 0 (offset 0)
# Ignoring wrong pointing object 649 0 (offset 0)
# Ignoring wrong pointing object 651 0 (offset 0)
# Ignoring wrong pointing object 653 0 (offset 0)
# Ignoring wrong pointing object 655 0 (offset 0)
# Ignoring wrong pointing object 657 0 (offset 0)
# Ignoring wrong pointing object 659 0 (offset 0)
# Ignoring wrong pointing object 661 0 (offset 0)
# Ignoring wrong pointing object 663 0 (offset 0)
# Ignoring wrong pointing object 665 0 (offset 0)
# Ignoring wrong pointing object 667 0 (offset 0)
# Ignoring wrong pointing object 669 0 (offset 0)
# Ignoring wrong pointing object 671 0 (offset 0)
# Ignoring wrong pointing object 726 0 (offset 0)
# Ignoring wrong pointing object 727 0 (offset 0)
#   Added 38 pages from 05_metrics.pdf
# Loading 07_green_software_research.pdf...
# Ignoring wrong pointing object 72 0 (offset 0)
# Ignoring wrong pointing object 221 0 (offset 0)
# Ignoring wrong pointing object 241 0 (offset 0)
# Ignoring wrong pointing object 247 0 (offset 0)
# Ignoring wrong pointing object 248 0 (offset 0)
# Ignoring wrong pointing object 249 0 (offset 0)
# Ignoring wrong pointing object 250 0 (offset 0)
# Ignoring wrong pointing object 251 0 (offset 0)
# Ignoring wrong pointing object 252 0 (offset 0)
# Ignoring wrong pointing object 253 0 (offset 0)
# Ignoring wrong pointing object 254 0 (offset 0)
# Ignoring wrong pointing object 255 0 (offset 0)
# Ignoring wrong pointing object 256 0 (offset 0)
# Ignoring wrong pointing object 257 0 (offset 0)
# Ignoring wrong pointing object 258 0 (offset 0)
# Ignoring wrong pointing object 335 0 (offset 0)
# Ignoring wrong pointing object 336 0 (offset 0)
#   Added 52 pages from 07_green_software_research.pdf
# Loading 08_green_ai.pdf...
# Ignoring wrong pointing object 62 0 (offset 0)
# Ignoring wrong pointing object 105 0 (offset 0)
# Ignoring wrong pointing object 108 0 (offset 0)
# Ignoring wrong pointing object 110 0 (offset 0)
# Ignoring wrong pointing object 112 0 (offset 0)
# Ignoring wrong pointing object 115 0 (offset 0)
# Ignoring wrong pointing object 116 0 (offset 0)
# Ignoring wrong pointing object 118 0 (offset 0)
# Ignoring wrong pointing object 122 0 (offset 0)
# Ignoring wrong pointing object 126 0 (offset 0)
# Ignoring wrong pointing object 128 0 (offset 0)
# Ignoring wrong pointing object 130 0 (offset 0)
# Ignoring wrong pointing object 132 0 (offset 0)
# Ignoring wrong pointing object 134 0 (offset 0)
# Ignoring wrong pointing object 136 0 (offset 0)
# Ignoring wrong pointing object 138 0 (offset 0)
# Ignoring wrong pointing object 140 0 (offset 0)
# Ignoring wrong pointing object 142 0 (offset 0)
# Ignoring wrong pointing object 144 0 (offset 0)
# Ignoring wrong pointing object 146 0 (offset 0)
# Ignoring wrong pointing object 151 0 (offset 0)
# Ignoring wrong pointing object 155 0 (offset 0)
# Ignoring wrong pointing object 161 0 (offset 0)
# Ignoring wrong pointing object 165 0 (offset 0)
# Ignoring wrong pointing object 178 0 (offset 0)
# Ignoring wrong pointing object 189 0 (offset 0)
# Ignoring wrong pointing object 282 0 (offset 0)
# Ignoring wrong pointing object 283 0 (offset 0)
#   Added 47 pages from 08_green_ai.pdf
# Loading 10_project2.pdf...
#   Added 30 pages from 10_project2.pdf
# Loading 11_SusSE Lecture - Neuromorphic computing 2025.pdf...
#   Added 65 pages from 11_SusSE Lecture - Neuromorphic computing 2025.pdf
# Loaded 340 document chunks.
# Setting up LLM and embedding models...
# Creating knowledge graph...
# Created initial knowledge graph with 340 nodes.
# Applying transforms to enhance knowledge graph...
# Applying HeadlinesExtractor:   9%|▊         | 29/340 [00:11<01:26,  3.61it/s]unable to apply transformation: Invalid json output: of the electricity consumed worldwide
# by 2040 will stem from ICT
# 14%
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying HeadlinesExtractor:  11%|█         | 38/340 [00:13<01:33,  3.24it/s]unable to apply transformation: Invalid json output: Software for Sustainability
# • We are not covering it in this course.
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying HeadlinesExtractor:  33%|███▎      | 112/340 [00:30<00:45,  5.05it/s]unable to apply transformation: Invalid json output: Problems in the Computer Language Benchmarks Game
# 34
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying HeadlinesExtractor:  37%|███▋      | 125/340 [00:34<00:54,  3.92it/s]unable to apply transformation: Invalid json output: t\nP\nTail Energy Consumption
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying HeadlinesExtractor:  58%|█████▊    | 198/340 [00:56<00:45,  3.13it/s]unable to apply transformation: Invalid json output: Tracing Analysis\n40
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying HeadlinesExtractor:  74%|███████▍  | 253/340 [01:14<00:19,  4.36it/s]unable to apply transformation: Invalid json output: Rethinking the Architecture: Spiking Neural Networks\n46
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying HeadlinesExtractor:  85%|████████▍ | 288/340 [01:23<00:11,  4.47it/s]unable to apply transformation: The LLM generation was not completed. Please increase the max_tokens and try again.
# Applying HeadlineSplitter:   0%|          | 0/340 [00:00<?, ?it/s]            unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# Applying KeyphrasesExtractor:   9%|▉         | 62/673 [00:24<02:11,  4.66it/s] unable to apply transformation: Failed to parse Keyphrases from completion 15. Got: 1 validation error for Keyphrases
#   Input should be a valid dictionary or instance of Keyphrases [type=model_type, input_value=15, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.10/v/model_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  12%|█▏        | 79/673 [00:29<01:37,  6.09it/s]unable to apply transformation: Invalid json output: Examples of Energy Profilers
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  21%|██        | 142/673 [00:53<03:01,  2.93it/s]unable to apply transformation: Invalid json output: • Carbon emissions
# ✅
# • How do we go from energy consumption to carbon consumption?
# 27
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  25%|██▌       | 171/673 [01:02<01:55,  4.36it/s]unable to apply transformation: Invalid json output: Luís Cruz
# L.Cruz@tudelft.nl
# 7. Green SE – Research
# Sustainable Software Engineering
# CS4575
# SustainableSE 2025
# Carolin Brandt
# C.E.Brandt@tudelft.nl
# Enrique Barba Roque
# E.BarbaRoque@tudelft.nl
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  27%|██▋       | 183/673 [01:06<02:23,  3.42it/s]unable to apply transformation: The LLM generation was not completed. Please increase the max_tokens and try again.
# Applying KeyphrasesExtractor:  28%|██▊       | 188/673 [01:09<04:41,  1.72it/s]unable to apply transformation: Failed to parse Keyphrases from completion 4. Got: 1 validation error for Keyphrases
#   Input should be a valid dictionary or instance of Keyphrases [type=model_type, input_value=4, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.10/v/model_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  34%|███▍      | 231/673 [01:27<03:01,  2.44it/s]unable to apply transformation: Invalid json output: Results: performance vs data shape
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  35%|███▌      | 237/673 [01:29<02:49,  2.57it/s]unable to apply transformation: Invalid json output: Results: energy vs data shape
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  37%|███▋      | 248/673 [01:33<02:08,  3.32it/s]unable to apply transformation: Invalid json output: DeepSeekMoE
# 30
# Preprint at ArXiv, 2024 https://arxiv.org/pdf/
# 2401.06066
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  42%|████▏     | 281/673 [01:48<04:16,  1.53it/s]unable to apply transformation: The LLM generation was not completed. Please increase the max_tokens and try again.
# Applying KeyphrasesExtractor:  50%|█████     | 338/673 [02:04<01:15,  4.45it/s]Property 'keyphrases' already exists in node 'e2af52'. Skipping!
# Applying KeyphrasesExtractor:  50%|█████     | 339/673 [02:04<01:18,  4.23it/s]Property 'keyphrases' already exists in node '1a69f5'. Skipping!
# Applying KeyphrasesExtractor:  51%|█████     | 341/673 [02:04<01:29,  3.73it/s]Property 'keyphrases' already exists in node 'f379da'. Skipping!
# Applying KeyphrasesExtractor:  51%|█████     | 343/673 [02:05<01:44,  3.16it/s]Property 'keyphrases' already exists in node 'b2accc'. Skipping!
# Applying KeyphrasesExtractor:  51%|█████     | 344/673 [02:06<02:13,  2.47it/s]Property 'keyphrases' already exists in node '7d0602'. Skipping!
# Applying KeyphrasesExtractor:  51%|█████▏    | 345/673 [02:06<01:56,  2.81it/s]Property 'keyphrases' already exists in node '76b315'. Skipping!
# Property 'keyphrases' already exists in node 'b2a28b'. Skipping!
# Applying KeyphrasesExtractor:  52%|█████▏    | 347/673 [02:07<01:50,  2.95it/s]Property 'keyphrases' already exists in node '373ca1'. Skipping!
# Applying KeyphrasesExtractor:  52%|█████▏    | 348/673 [02:07<01:54,  2.85it/s]Property 'keyphrases' already exists in node '4b81f3'. Skipping!
# Property 'keyphrases' already exists in node '0dc166'. Skipping!
# Applying KeyphrasesExtractor:  52%|█████▏    | 350/673 [02:07<01:36,  3.36it/s]Property 'keyphrases' already exists in node '4a417f'. Skipping!
# Applying KeyphrasesExtractor:  52%|█████▏    | 351/673 [02:08<01:28,  3.63it/s]Property 'keyphrases' already exists in node '5eca77'. Skipping!
# Applying KeyphrasesExtractor:  52%|█████▏    | 352/673 [02:08<01:35,  3.37it/s]Property 'keyphrases' already exists in node '650215'. Skipping!
# Applying KeyphrasesExtractor:  52%|█████▏    | 353/673 [02:08<01:29,  3.59it/s]Property 'keyphrases' already exists in node '707a69'. Skipping!
# Applying KeyphrasesExtractor:  53%|█████▎    | 354/673 [02:08<01:14,  4.27it/s]Property 'keyphrases' already exists in node 'ea2330'. Skipping!
# Applying KeyphrasesExtractor:  53%|█████▎    | 355/673 [02:09<01:24,  3.74it/s]Property 'keyphrases' already exists in node '7859c1'. Skipping!
# Applying KeyphrasesExtractor:  53%|█████▎    | 356/673 [02:10<02:21,  2.24it/s]Property 'keyphrases' already exists in node '33ea3d'. Skipping!
# Property 'keyphrases' already exists in node '181499'. Skipping!
# Applying KeyphrasesExtractor:  53%|█████▎    | 358/673 [02:10<01:45,  3.00it/s]Property 'keyphrases' already exists in node 'b82643'. Skipping!
# Property 'keyphrases' already exists in node '41840c'. Skipping!
# Applying KeyphrasesExtractor:  53%|█████▎    | 360/673 [02:10<01:27,  3.59it/s]Property 'keyphrases' already exists in node 'b36e8a'. Skipping!
# Applying KeyphrasesExtractor:  54%|█████▎    | 361/673 [02:11<01:33,  3.34it/s]Property 'keyphrases' already exists in node 'cfe2cf'. Skipping!
# Property 'keyphrases' already exists in node '458f6e'. Skipping!
# Applying KeyphrasesExtractor:  54%|█████▍    | 363/673 [02:11<01:32,  3.35it/s]Property 'keyphrases' already exists in node 'b98b94'. Skipping!
# Applying KeyphrasesExtractor:  54%|█████▍    | 364/673 [02:14<03:37,  1.42it/s]Property 'keyphrases' already exists in node 'e0fc89'. Skipping!
# Applying KeyphrasesExtractor:  54%|█████▍    | 365/673 [02:16<05:23,  1.05s/it]Property 'keyphrases' already exists in node '5096ba'. Skipping!
# Property 'keyphrases' already exists in node '39cfed'. Skipping!
# Applying KeyphrasesExtractor:  55%|█████▍    | 367/673 [02:17<04:13,  1.21it/s]Property 'keyphrases' already exists in node '2736b1'. Skipping!
# Property 'keyphrases' already exists in node '2da30f'. Skipping!
# Applying KeyphrasesExtractor:  55%|█████▍    | 369/673 [02:17<03:00,  1.68it/s]Property 'keyphrases' already exists in node '0cba3a'. Skipping!
# Applying KeyphrasesExtractor:  55%|█████▍    | 370/673 [02:19<03:56,  1.28it/s]Property 'keyphrases' already exists in node '5aaabe'. Skipping!
# Applying KeyphrasesExtractor:  55%|█████▌    | 371/673 [02:19<03:24,  1.48it/s]Property 'keyphrases' already exists in node '2fe611'. Skipping!
# Applying KeyphrasesExtractor:  55%|█████▌    | 372/673 [02:20<03:49,  1.31it/s]Property 'keyphrases' already exists in node '60dcd3'. Skipping!
# Applying KeyphrasesExtractor:  55%|█████▌    | 373/673 [02:20<03:07,  1.60it/s]Property 'keyphrases' already exists in node 'e3182f'. Skipping!
# Applying KeyphrasesExtractor:  56%|█████▌    | 374/673 [02:20<02:45,  1.81it/s]Property 'keyphrases' already exists in node '72b4c8'. Skipping!
# Property 'keyphrases' already exists in node '1582d3'. Skipping!
# Applying KeyphrasesExtractor:  56%|█████▌    | 376/673 [02:21<01:49,  2.71it/s]Property 'keyphrases' already exists in node '38cfcc'. Skipping!
# Applying KeyphrasesExtractor:  56%|█████▌    | 377/673 [02:21<01:43,  2.86it/s]Property 'keyphrases' already exists in node '9bec9a'. Skipping!
# Applying KeyphrasesExtractor:  56%|█████▌    | 378/673 [02:21<01:34,  3.14it/s]Property 'keyphrases' already exists in node '2b9151'. Skipping!
# Applying KeyphrasesExtractor:  56%|█████▋    | 379/673 [02:21<01:22,  3.57it/s]Property 'keyphrases' already exists in node '61b4f8'. Skipping!
# Applying KeyphrasesExtractor:  56%|█████▋    | 380/673 [02:22<01:47,  2.74it/s]Property 'keyphrases' already exists in node 'e287ef'. Skipping!
# Applying KeyphrasesExtractor:  57%|█████▋    | 381/673 [02:23<02:22,  2.06it/s]Property 'keyphrases' already exists in node '20d7c8'. Skipping!
# Applying KeyphrasesExtractor:  57%|█████▋    | 382/673 [02:23<02:03,  2.35it/s]Property 'keyphrases' already exists in node '91ea36'. Skipping!
# Applying KeyphrasesExtractor:  57%|█████▋    | 383/673 [02:23<01:52,  2.59it/s]Property 'keyphrases' already exists in node 'c104b9'. Skipping!
# Applying KeyphrasesExtractor:  57%|█████▋    | 384/673 [02:24<01:58,  2.45it/s]Property 'keyphrases' already exists in node '49fc73'. Skipping!
# Applying KeyphrasesExtractor:  57%|█████▋    | 385/673 [02:24<01:44,  2.75it/s]Property 'keyphrases' already exists in node 'd073f5'. Skipping!
# Property 'keyphrases' already exists in node 'b2cd00'. Skipping!
# Applying KeyphrasesExtractor:  58%|█████▊    | 387/673 [02:24<01:09,  4.11it/s]Property 'keyphrases' already exists in node '726f54'. Skipping!
# Applying KeyphrasesExtractor:  58%|█████▊    | 388/673 [02:25<01:27,  3.25it/s]Property 'keyphrases' already exists in node 'ae5b9b'. Skipping!
# Applying KeyphrasesExtractor:  58%|█████▊    | 389/673 [02:25<01:19,  3.58it/s]Property 'keyphrases' already exists in node '6505a0'. Skipping!
# Applying KeyphrasesExtractor:  58%|█████▊    | 390/673 [02:25<01:29,  3.17it/s]Property 'keyphrases' already exists in node '46f762'. Skipping!
# Applying KeyphrasesExtractor:  58%|█████▊    | 391/673 [02:26<01:17,  3.65it/s]Property 'keyphrases' already exists in node '1814f8'. Skipping!
# Applying KeyphrasesExtractor:  58%|█████▊    | 392/673 [02:26<01:31,  3.09it/s]Property 'keyphrases' already exists in node '70dabc'. Skipping!
# Applying KeyphrasesExtractor:  58%|█████▊    | 393/673 [02:26<01:20,  3.49it/s]Property 'keyphrases' already exists in node 'a28d1e'. Skipping!
# Applying KeyphrasesExtractor:  59%|█████▊    | 394/673 [02:26<01:14,  3.73it/s]Property 'keyphrases' already exists in node '567524'. Skipping!
# Applying KeyphrasesExtractor:  59%|█████▊    | 395/673 [02:27<01:07,  4.14it/s]Property 'keyphrases' already exists in node 'a42620'. Skipping!
# Applying KeyphrasesExtractor:  59%|█████▉    | 396/673 [02:27<01:29,  3.11it/s]Property 'keyphrases' already exists in node '6310b6'. Skipping!
# Applying KeyphrasesExtractor:  59%|█████▉    | 397/673 [02:27<01:25,  3.21it/s]Property 'keyphrases' already exists in node '13ac96'. Skipping!
# Applying KeyphrasesExtractor:  59%|█████▉    | 398/673 [02:28<01:20,  3.41it/s]Property 'keyphrases' already exists in node 'cddbb1'. Skipping!
# Applying KeyphrasesExtractor:  59%|█████▉    | 399/673 [02:28<01:15,  3.64it/s]Property 'keyphrases' already exists in node '5c46e6'. Skipping!
# Applying KeyphrasesExtractor:  59%|█████▉    | 400/673 [02:28<01:32,  2.96it/s]unable to apply transformation: Failed to parse Keyphrases from completion 15. Got: 1 validation error for Keyphrases
#   Input should be a valid dictionary or instance of Keyphrases [type=model_type, input_value=15, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.10/v/model_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  60%|█████▉    | 401/673 [02:29<01:39,  2.72it/s]Property 'keyphrases' already exists in node '16ddf0'. Skipping!
# Applying KeyphrasesExtractor:  60%|█████▉    | 402/673 [02:29<01:32,  2.92it/s]Property 'keyphrases' already exists in node 'e53efc'. Skipping!
# Property 'keyphrases' already exists in node 'f64bfa'. Skipping!
# Applying KeyphrasesExtractor:  60%|██████    | 404/673 [02:29<01:11,  3.74it/s]Property 'keyphrases' already exists in node '230078'. Skipping!
# Applying KeyphrasesExtractor:  60%|██████    | 405/673 [02:30<01:36,  2.79it/s]Property 'keyphrases' already exists in node '273a10'. Skipping!
# Property 'keyphrases' already exists in node 'b7df23'. Skipping!
# Applying KeyphrasesExtractor:  60%|██████    | 407/673 [02:30<01:03,  4.20it/s]Property 'keyphrases' already exists in node '1b5913'. Skipping!
# Applying KeyphrasesExtractor:  61%|██████    | 408/673 [02:31<01:16,  3.48it/s]Property 'keyphrases' already exists in node '85b179'. Skipping!
# Applying KeyphrasesExtractor:  61%|██████    | 409/673 [02:31<01:24,  3.11it/s]Property 'keyphrases' already exists in node '399ff9'. Skipping!
# Applying KeyphrasesExtractor:  61%|██████    | 410/673 [02:31<01:22,  3.18it/s]Property 'keyphrases' already exists in node 'c3a0a8'. Skipping!
# Applying KeyphrasesExtractor:  61%|██████    | 411/673 [02:32<01:43,  2.54it/s]Property 'keyphrases' already exists in node '06c3ba'. Skipping!
# Property 'keyphrases' already exists in node '99c393'. Skipping!
# Property 'keyphrases' already exists in node '9327cf'. Skipping!
# Applying KeyphrasesExtractor:  62%|██████▏   | 414/673 [02:32<01:03,  4.08it/s]Property 'keyphrases' already exists in node 'd62af4'. Skipping!
# Applying KeyphrasesExtractor:  62%|██████▏   | 415/673 [02:33<01:29,  2.88it/s]Property 'keyphrases' already exists in node '4370d7'. Skipping!
# Applying KeyphrasesExtractor:  62%|██████▏   | 416/673 [02:34<01:47,  2.38it/s]Property 'keyphrases' already exists in node '3ab3e1'. Skipping!
# Applying KeyphrasesExtractor:  62%|██████▏   | 417/673 [02:34<01:31,  2.80it/s]Property 'keyphrases' already exists in node '6337db'. Skipping!
# Applying KeyphrasesExtractor:  62%|██████▏   | 418/673 [02:34<01:23,  3.05it/s]Property 'keyphrases' already exists in node '8fe991'. Skipping!
# unable to apply transformation: Invalid json output: Examples of Energy Profilers
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  62%|██████▏   | 420/673 [02:34<00:55,  4.59it/s]Property 'keyphrases' already exists in node '6494e4'. Skipping!
# Applying KeyphrasesExtractor:  63%|██████▎   | 421/673 [02:35<01:02,  4.03it/s]Property 'keyphrases' already exists in node 'cf39e6'. Skipping!
# Applying KeyphrasesExtractor:  63%|██████▎   | 422/673 [02:35<00:54,  4.57it/s]Property 'keyphrases' already exists in node '4880d3'. Skipping!
# Applying KeyphrasesExtractor:  63%|██████▎   | 423/673 [02:35<00:53,  4.71it/s]Property 'keyphrases' already exists in node '88f445'. Skipping!
# Applying KeyphrasesExtractor:  63%|██████▎   | 424/673 [02:35<00:53,  4.68it/s]Property 'keyphrases' already exists in node '5936bd'. Skipping!
# Applying KeyphrasesExtractor:  63%|██████▎   | 425/673 [02:36<01:03,  3.90it/s]Property 'keyphrases' already exists in node '2ee51b'. Skipping!
# Property 'keyphrases' already exists in node 'f5e380'. Skipping!
# Applying KeyphrasesExtractor:  63%|██████▎   | 427/673 [02:36<00:43,  5.68it/s]Property 'keyphrases' already exists in node 'a0c9e8'. Skipping!
# Applying KeyphrasesExtractor:  64%|██████▎   | 428/673 [02:36<00:55,  4.38it/s]Property 'keyphrases' already exists in node '0366e5'. Skipping!
# Applying KeyphrasesExtractor:  64%|██████▎   | 429/673 [02:36<00:54,  4.49it/s]Property 'keyphrases' already exists in node '69b21e'. Skipping!
# Applying KeyphrasesExtractor:  64%|██████▍   | 430/673 [02:37<00:59,  4.10it/s]Property 'keyphrases' already exists in node '827b59'. Skipping!
# Property 'keyphrases' already exists in node '5fba31'. Skipping!
# Applying KeyphrasesExtractor:  64%|██████▍   | 432/673 [02:38<01:23,  2.87it/s]Property 'keyphrases' already exists in node 'c0b623'. Skipping!
# Property 'keyphrases' already exists in node 'b0b329'. Skipping!
# Applying KeyphrasesExtractor:  64%|██████▍   | 434/673 [02:39<01:42,  2.33it/s]Property 'keyphrases' already exists in node 'b24ab7'. Skipping!
# Applying KeyphrasesExtractor:  65%|██████▍   | 435/673 [02:39<01:29,  2.67it/s]Property 'keyphrases' already exists in node '14466c'. Skipping!
# Applying KeyphrasesExtractor:  65%|██████▍   | 436/673 [02:39<01:14,  3.19it/s]Property 'keyphrases' already exists in node '6073c4'. Skipping!
# Property 'keyphrases' already exists in node 'fb4b00'. Skipping!
# Applying KeyphrasesExtractor:  65%|██████▍   | 437/673 [02:39<01:01,  3.83it/s]Property 'keyphrases' already exists in node 'c16702'. Skipping!
# Applying KeyphrasesExtractor:  65%|██████▌   | 439/673 [02:40<00:53,  4.39it/s]Property 'keyphrases' already exists in node '2448b9'. Skipping!
# Applying KeyphrasesExtractor:  65%|██████▌   | 440/673 [02:40<00:55,  4.23it/s]Property 'keyphrases' already exists in node 'a5da21'. Skipping!
# Applying KeyphrasesExtractor:  66%|██████▌   | 441/673 [02:41<01:24,  2.73it/s]Property 'keyphrases' already exists in node 'f2e216'. Skipping!
# Applying KeyphrasesExtractor:  66%|██████▌   | 442/673 [02:41<01:44,  2.22it/s]Property 'keyphrases' already exists in node '51387d'. Skipping!
# Property 'keyphrases' already exists in node '44975b'. Skipping!
# Applying KeyphrasesExtractor:  66%|██████▌   | 444/673 [02:41<01:08,  3.35it/s]Property 'keyphrases' already exists in node 'fe1aa5'. Skipping!
# Applying KeyphrasesExtractor:  66%|██████▌   | 445/673 [02:42<01:25,  2.68it/s]Property 'keyphrases' already exists in node '7c358f'. Skipping!
# Applying KeyphrasesExtractor:  66%|██████▋   | 446/673 [02:43<01:55,  1.96it/s]Property 'keyphrases' already exists in node '133e68'. Skipping!
# Applying KeyphrasesExtractor:  66%|██████▋   | 447/673 [02:44<02:23,  1.58it/s]Property 'keyphrases' already exists in node 'c3294f'. Skipping!
# Applying KeyphrasesExtractor:  67%|██████▋   | 448/673 [02:45<02:52,  1.30it/s]Property 'keyphrases' already exists in node '2f868b'. Skipping!
# Property 'keyphrases' already exists in node 'ef9894'. Skipping!
# Applying KeyphrasesExtractor:  67%|██████▋   | 450/673 [02:45<01:49,  2.04it/s]Property 'keyphrases' already exists in node 'fcf33b'. Skipping!
# Applying KeyphrasesExtractor:  67%|██████▋   | 451/673 [02:47<02:34,  1.43it/s]Property 'keyphrases' already exists in node '6275c0'. Skipping!
# Applying KeyphrasesExtractor:  67%|██████▋   | 452/673 [02:49<03:40,  1.00it/s]Property 'keyphrases' already exists in node 'dc5f9c'. Skipping!
# Applying KeyphrasesExtractor:  67%|██████▋   | 453/673 [02:49<02:47,  1.32it/s]Property 'keyphrases' already exists in node '3516c5'. Skipping!
# Property 'keyphrases' already exists in node '1e48cf'. Skipping!
# Applying KeyphrasesExtractor:  68%|██████▊   | 455/673 [02:49<01:39,  2.19it/s]Property 'keyphrases' already exists in node '84e0b1'. Skipping!
# Applying KeyphrasesExtractor:  68%|██████▊   | 456/673 [02:49<01:25,  2.54it/s]Property 'keyphrases' already exists in node '1f3a80'. Skipping!
# Property 'keyphrases' already exists in node 'e33eb3'. Skipping!
# Applying KeyphrasesExtractor:  68%|██████▊   | 458/673 [02:49<01:01,  3.49it/s]Property 'keyphrases' already exists in node '1d21b9'. Skipping!
# Applying KeyphrasesExtractor:  68%|██████▊   | 460/673 [02:50<01:14,  2.85it/s]Property 'keyphrases' already exists in node '15be50'. Skipping!
# Applying KeyphrasesExtractor:  68%|██████▊   | 461/673 [02:50<01:07,  3.15it/s]Property 'keyphrases' already exists in node 'bc4f66'. Skipping!
# Applying KeyphrasesExtractor:  69%|██████▊   | 462/673 [02:50<00:57,  3.67it/s]Property 'keyphrases' already exists in node '697ef4'. Skipping!
# Applying KeyphrasesExtractor:  69%|██████▉   | 463/673 [02:51<01:06,  3.17it/s]Property 'keyphrases' already exists in node 'e4df76'. Skipping!
# Applying KeyphrasesExtractor:  69%|██████▉   | 464/673 [02:51<01:00,  3.47it/s]Property 'keyphrases' already exists in node '881306'. Skipping!
# Applying KeyphrasesExtractor:  69%|██████▉   | 465/673 [02:51<00:53,  3.91it/s]Property 'keyphrases' already exists in node '4097af'. Skipping!
# Applying KeyphrasesExtractor:  69%|██████▉   | 466/673 [02:53<01:57,  1.76it/s]Property 'keyphrases' already exists in node 'ca95f2'. Skipping!
# Property 'keyphrases' already exists in node '70d96e'. Skipping!
# Applying KeyphrasesExtractor:  70%|██████▉   | 468/673 [02:53<01:13,  2.78it/s]Property 'keyphrases' already exists in node '497c35'. Skipping!
# Applying KeyphrasesExtractor:  70%|██████▉   | 469/673 [02:53<01:14,  2.73it/s]Property 'keyphrases' already exists in node '1cf4fd'. Skipping!
# Applying KeyphrasesExtractor:  70%|██████▉   | 470/673 [02:53<01:09,  2.92it/s]Property 'keyphrases' already exists in node '0711c8'. Skipping!
# Applying KeyphrasesExtractor:  70%|██████▉   | 471/673 [02:54<01:31,  2.21it/s]Property 'keyphrases' already exists in node 'c37594'. Skipping!
# Property 'keyphrases' already exists in node '131391'. Skipping!
# Applying KeyphrasesExtractor:  70%|███████   | 473/673 [02:54<00:56,  3.51it/s]Property 'keyphrases' already exists in node '8b2361'. Skipping!
# Applying KeyphrasesExtractor:  70%|███████   | 474/673 [02:54<00:49,  4.02it/s]unable to apply transformation: Invalid json output: ∫
# tf=9
# ti=1
# P(t)dt
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  71%|███████   | 475/673 [02:55<00:41,  4.73it/s]Property 'keyphrases' already exists in node '34d678'. Skipping!
# Property 'keyphrases' already exists in node 'a29dc0'. Skipping!
# Applying KeyphrasesExtractor:  71%|███████   | 477/673 [02:55<00:51,  3.83it/s]unable to apply transformation: Invalid json output: • Carbon emissions
# ✅
# • How do we go from energy consumption to carbon consumption?
# 27
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  71%|███████   | 478/673 [02:56<01:05,  2.98it/s]Property 'keyphrases' already exists in node '5448c6'. Skipping!
# Applying KeyphrasesExtractor:  71%|███████   | 479/673 [02:57<01:28,  2.19it/s]Property 'keyphrases' already exists in node 'cbb321'. Skipping!
# Property 'keyphrases' already exists in node 'ed4765'. Skipping!
# Applying KeyphrasesExtractor:  71%|███████▏  | 481/673 [02:57<01:11,  2.68it/s]Property 'keyphrases' already exists in node '50fe0b'. Skipping!
# Applying KeyphrasesExtractor:  72%|███████▏  | 482/673 [02:57<01:09,  2.74it/s]Property 'keyphrases' already exists in node '45ac64'. Skipping!
# Property 'keyphrases' already exists in node '01f0a0'. Skipping!
# Applying KeyphrasesExtractor:  72%|███████▏  | 484/673 [02:58<00:55,  3.42it/s]Property 'keyphrases' already exists in node '025eb3'. Skipping!
# Property 'keyphrases' already exists in node 'fbc538'. Skipping!
# Applying KeyphrasesExtractor:  72%|███████▏  | 486/673 [02:58<00:55,  3.34it/s]Property 'keyphrases' already exists in node '2e3c70'. Skipping!
# Applying KeyphrasesExtractor:  72%|███████▏  | 487/673 [02:59<00:49,  3.74it/s]Property 'keyphrases' already exists in node '091c67'. Skipping!
# Property 'keyphrases' already exists in node 'fac549'. Skipping!
# Property 'keyphrases' already exists in node 'db19ac'. Skipping!
# Applying KeyphrasesExtractor:  73%|███████▎  | 490/673 [02:59<00:30,  5.99it/s]Property 'keyphrases' already exists in node '1bf741'. Skipping!
# Applying KeyphrasesExtractor:  73%|███████▎  | 491/673 [02:59<00:46,  3.95it/s]Property 'keyphrases' already exists in node 'f209ff'. Skipping!
# Applying KeyphrasesExtractor:  73%|███████▎  | 492/673 [03:00<00:40,  4.42it/s]Property 'keyphrases' already exists in node '739291'. Skipping!
# Applying KeyphrasesExtractor:  73%|███████▎  | 493/673 [03:00<00:35,  5.06it/s]Property 'keyphrases' already exists in node '842006'. Skipping!
# Applying KeyphrasesExtractor:  74%|███████▎  | 495/673 [03:00<00:37,  4.69it/s]Property 'keyphrases' already exists in node '9dbbea'. Skipping!
# Applying KeyphrasesExtractor:  74%|███████▎  | 496/673 [03:00<00:44,  4.00it/s]Property 'keyphrases' already exists in node 'b75c84'. Skipping!
# Applying KeyphrasesExtractor:  74%|███████▍  | 497/673 [03:01<00:46,  3.75it/s]Property 'keyphrases' already exists in node 'f7e162'. Skipping!
# Applying KeyphrasesExtractor:  74%|███████▍  | 498/673 [03:01<00:51,  3.38it/s]Property 'keyphrases' already exists in node '800b82'. Skipping!
# Property 'keyphrases' already exists in node '3af62c'. Skipping!
# Applying KeyphrasesExtractor:  74%|███████▍  | 500/673 [03:01<00:40,  4.26it/s]Property 'keyphrases' already exists in node '5f9098'. Skipping!
# Applying KeyphrasesExtractor:  74%|███████▍  | 501/673 [03:02<01:01,  2.80it/s]Property 'keyphrases' already exists in node 'de2114'. Skipping!
# Applying KeyphrasesExtractor:  75%|███████▍  | 502/673 [03:03<01:38,  1.74it/s]Property 'keyphrases' already exists in node '18e9bc'. Skipping!
# Applying KeyphrasesExtractor:  75%|███████▍  | 503/673 [03:04<01:17,  2.21it/s]Property 'keyphrases' already exists in node '353561'. Skipping!
# Property 'keyphrases' already exists in node '951fd0'. Skipping!
# Applying KeyphrasesExtractor:  75%|███████▌  | 505/673 [03:04<00:47,  3.50it/s]Property 'keyphrases' already exists in node '5c6455'. Skipping!
# Applying KeyphrasesExtractor:  75%|███████▌  | 506/673 [03:04<00:41,  4.04it/s]Property 'keyphrases' already exists in node 'b73481'. Skipping!
# Applying KeyphrasesExtractor:  75%|███████▌  | 507/673 [03:04<00:40,  4.05it/s]Property 'keyphrases' already exists in node '45376d'. Skipping!
# Applying KeyphrasesExtractor:  75%|███████▌  | 508/673 [03:05<00:49,  3.30it/s]Property 'keyphrases' already exists in node '7ce461'. Skipping!
# Applying KeyphrasesExtractor:  76%|███████▌  | 509/673 [03:05<00:44,  3.68it/s]Property 'keyphrases' already exists in node 'b14369'. Skipping!
# Applying KeyphrasesExtractor:  76%|███████▌  | 510/673 [03:05<00:40,  3.99it/s]Property 'keyphrases' already exists in node '4bf715'. Skipping!
# Applying KeyphrasesExtractor:  76%|███████▌  | 512/673 [03:06<00:59,  2.73it/s]Property 'keyphrases' already exists in node 'e62910'. Skipping!
# Applying KeyphrasesExtractor:  76%|███████▌  | 513/673 [03:06<00:51,  3.12it/s]Property 'keyphrases' already exists in node '2ade6d'. Skipping!
# Applying KeyphrasesExtractor:  76%|███████▋  | 514/673 [03:06<00:41,  3.79it/s]Property 'keyphrases' already exists in node '5c07ae'. Skipping!
# Applying KeyphrasesExtractor:  77%|███████▋  | 515/673 [03:06<00:34,  4.64it/s]Property 'keyphrases' already exists in node 'db42cf'. Skipping!
# Applying KeyphrasesExtractor:  77%|███████▋  | 516/673 [03:07<00:47,  3.29it/s]Property 'keyphrases' already exists in node 'e9e1c5'. Skipping!
# Applying KeyphrasesExtractor:  77%|███████▋  | 517/673 [03:08<01:15,  2.07it/s]Property 'keyphrases' already exists in node 'de7049'. Skipping!
# Property 'keyphrases' already exists in node '373bda'. Skipping!
# Property 'keyphrases' already exists in node 'e7e8f0'. Skipping!
# Applying KeyphrasesExtractor:  77%|███████▋  | 520/673 [03:09<00:58,  2.61it/s]Property 'keyphrases' already exists in node '6b9b97'. Skipping!
# Applying KeyphrasesExtractor:  77%|███████▋  | 521/673 [03:09<00:56,  2.71it/s]Property 'keyphrases' already exists in node '83bee6'. Skipping!
# Applying KeyphrasesExtractor:  78%|███████▊  | 522/673 [03:09<00:48,  3.09it/s]Property 'keyphrases' already exists in node 'd14dd1'. Skipping!
# Property 'keyphrases' already exists in node '893c3e'. Skipping!
# Applying KeyphrasesExtractor:  78%|███████▊  | 524/673 [03:10<00:53,  2.77it/s]Property 'keyphrases' already exists in node 'ef6b61'. Skipping!
# Applying KeyphrasesExtractor:  78%|███████▊  | 525/673 [03:10<00:46,  3.20it/s]Property 'keyphrases' already exists in node '8e7cfc'. Skipping!
# Applying KeyphrasesExtractor:  78%|███████▊  | 526/673 [03:10<00:44,  3.28it/s]Property 'keyphrases' already exists in node '90573b'. Skipping!
# Property 'keyphrases' already exists in node '309ffc'. Skipping!
# Applying KeyphrasesExtractor:  78%|███████▊  | 528/673 [03:11<00:33,  4.28it/s]Property 'keyphrases' already exists in node '455e51'. Skipping!
# Applying KeyphrasesExtractor:  79%|███████▊  | 529/673 [03:11<00:42,  3.39it/s]Property 'keyphrases' already exists in node 'f3f17c'. Skipping!
# Applying KeyphrasesExtractor:  79%|███████▉  | 530/673 [03:12<01:04,  2.21it/s]Property 'keyphrases' already exists in node '126087'. Skipping!
# Property 'keyphrases' already exists in node 'f69842'. Skipping!
# Applying KeyphrasesExtractor:  79%|███████▉  | 532/673 [03:13<01:00,  2.33it/s]Property 'keyphrases' already exists in node 'a81270'. Skipping!
# Applying KeyphrasesExtractor:  79%|███████▉  | 533/673 [03:13<00:55,  2.50it/s]Property 'keyphrases' already exists in node '5159a9'. Skipping!
# Applying KeyphrasesExtractor:  79%|███████▉  | 534/673 [03:14<01:19,  1.75it/s]Property 'keyphrases' already exists in node 'c519e7'. Skipping!
# Applying KeyphrasesExtractor:  79%|███████▉  | 535/673 [03:16<01:53,  1.22it/s]Property 'keyphrases' already exists in node 'e1966a'. Skipping!
# Applying KeyphrasesExtractor:  80%|███████▉  | 536/673 [03:17<02:06,  1.08it/s]Property 'keyphrases' already exists in node '3370be'. Skipping!
# Applying KeyphrasesExtractor:  80%|███████▉  | 537/673 [03:17<01:41,  1.34it/s]Property 'keyphrases' already exists in node 'd32dc5'. Skipping!
# Applying KeyphrasesExtractor:  80%|███████▉  | 538/673 [03:18<01:57,  1.15it/s]Property 'keyphrases' already exists in node '6d94c1'. Skipping!
# Applying KeyphrasesExtractor:  80%|████████  | 539/673 [03:20<02:18,  1.04s/it]Property 'keyphrases' already exists in node '8097f2'. Skipping!
# Applying KeyphrasesExtractor:  80%|████████  | 540/673 [03:20<01:48,  1.23it/s]Property 'keyphrases' already exists in node 'f7a43c'. Skipping!
# Applying KeyphrasesExtractor:  80%|████████  | 541/673 [03:20<01:27,  1.52it/s]Property 'keyphrases' already exists in node 'b0a246'. Skipping!
# Property 'keyphrases' already exists in node 'cad37e'. Skipping!
# Applying KeyphrasesExtractor:  81%|████████  | 543/673 [03:21<00:49,  2.61it/s]Property 'keyphrases' already exists in node '824d55'. Skipping!
# Applying KeyphrasesExtractor:  81%|████████  | 544/673 [03:21<01:01,  2.11it/s]Property 'keyphrases' already exists in node '78dbc3'. Skipping!
# Applying KeyphrasesExtractor:  81%|████████  | 545/673 [03:22<01:09,  1.84it/s]Property 'keyphrases' already exists in node '39f16c'. Skipping!
# Property 'keyphrases' already exists in node 'f217f6'. Skipping!
# Applying KeyphrasesExtractor:  81%|████████▏ | 547/673 [03:22<00:43,  2.88it/s]Property 'keyphrases' already exists in node 'cab323'. Skipping!
# Property 'keyphrases' already exists in node 'eee391'. Skipping!
# Applying KeyphrasesExtractor:  82%|████████▏ | 549/673 [03:23<00:43,  2.86it/s]Property 'keyphrases' already exists in node '504e16'. Skipping!
# Applying KeyphrasesExtractor:  82%|████████▏ | 552/673 [03:23<00:32,  3.71it/s]Property 'keyphrases' already exists in node 'e260c0'. Skipping!
# Applying KeyphrasesExtractor:  82%|████████▏ | 553/673 [03:24<00:31,  3.75it/s]Property 'keyphrases' already exists in node 'f5485e'. Skipping!
# Applying KeyphrasesExtractor:  82%|████████▏ | 554/673 [03:24<00:31,  3.82it/s]Property 'keyphrases' already exists in node 'd7febf'. Skipping!
# Applying KeyphrasesExtractor:  82%|████████▏ | 555/673 [03:24<00:27,  4.30it/s]Property 'keyphrases' already exists in node 'abce2b'. Skipping!
# Applying KeyphrasesExtractor:  83%|████████▎ | 556/673 [03:24<00:29,  3.95it/s]Property 'keyphrases' already exists in node 'f50d21'. Skipping!
# Property 'keyphrases' already exists in node '070888'. Skipping!
# Applying KeyphrasesExtractor:  83%|████████▎ | 558/673 [03:26<00:46,  2.48it/s]Property 'keyphrases' already exists in node 'bd7e54'. Skipping!
# Applying KeyphrasesExtractor:  83%|████████▎ | 559/673 [03:26<00:38,  2.98it/s]Property 'keyphrases' already exists in node '688ed9'. Skipping!
# Applying KeyphrasesExtractor:  83%|████████▎ | 560/673 [03:26<00:36,  3.12it/s]Property 'keyphrases' already exists in node 'c208c4'. Skipping!
# Property 'keyphrases' already exists in node '499e6e'. Skipping!
# Property 'keyphrases' already exists in node '036fcc'. Skipping!
# Applying KeyphrasesExtractor:  84%|████████▎ | 563/673 [03:27<00:35,  3.09it/s]Property 'keyphrases' already exists in node 'd55584'. Skipping!
# Property 'keyphrases' already exists in node 'aafdeb'. Skipping!
# Applying KeyphrasesExtractor:  84%|████████▍ | 565/673 [03:27<00:28,  3.84it/s]Property 'keyphrases' already exists in node '5f2ddc'. Skipping!
# Applying KeyphrasesExtractor:  84%|████████▍ | 566/673 [03:28<00:29,  3.63it/s]Property 'keyphrases' already exists in node 'd6ee7f'. Skipping!
# Applying KeyphrasesExtractor:  84%|████████▍ | 567/673 [03:28<00:26,  4.01it/s]Property 'keyphrases' already exists in node 'f10a76'. Skipping!
# Applying KeyphrasesExtractor:  84%|████████▍ | 568/673 [03:28<00:25,  4.20it/s]Property 'keyphrases' already exists in node 'a928b1'. Skipping!
# Applying KeyphrasesExtractor:  85%|████████▍ | 570/673 [03:28<00:18,  5.44it/s]Property 'keyphrases' already exists in node '578473'. Skipping!
# Applying KeyphrasesExtractor:  85%|████████▍ | 571/673 [03:28<00:17,  5.78it/s]Property 'keyphrases' already exists in node '3e743e'. Skipping!
# Applying KeyphrasesExtractor:  85%|████████▍ | 572/673 [03:29<00:22,  4.54it/s]Property 'keyphrases' already exists in node '32014b'. Skipping!
# Applying KeyphrasesExtractor:  85%|████████▌ | 573/673 [03:29<00:29,  3.35it/s]Property 'keyphrases' already exists in node '95a4dc'. Skipping!
# Property 'keyphrases' already exists in node 'a2c923'. Skipping!
# Applying KeyphrasesExtractor:  85%|████████▌ | 575/673 [03:30<00:28,  3.39it/s]Property 'keyphrases' already exists in node 'bf973b'. Skipping!
# Applying KeyphrasesExtractor:  86%|████████▌ | 576/673 [03:30<00:36,  2.69it/s]Property 'keyphrases' already exists in node '1000fc'. Skipping!
# Applying KeyphrasesExtractor:  86%|████████▌ | 577/673 [03:30<00:29,  3.27it/s]Property 'keyphrases' already exists in node '656612'. Skipping!
# Applying KeyphrasesExtractor:  86%|████████▌ | 578/673 [03:31<00:44,  2.12it/s]Property 'keyphrases' already exists in node '28d1ea'. Skipping!
# Applying KeyphrasesExtractor:  86%|████████▌ | 580/673 [03:32<00:35,  2.59it/s]Property 'keyphrases' already exists in node '617e25'. Skipping!
# Applying KeyphrasesExtractor:  86%|████████▋ | 581/673 [03:32<00:33,  2.72it/s]Property 'keyphrases' already exists in node 'c84c19'. Skipping!
# Applying KeyphrasesExtractor:  86%|████████▋ | 582/673 [03:32<00:27,  3.32it/s]Property 'keyphrases' already exists in node '41ea6d'. Skipping!
# Applying KeyphrasesExtractor:  87%|████████▋ | 583/673 [03:33<00:25,  3.56it/s]Property 'keyphrases' already exists in node 'dcb919'. Skipping!
# Property 'keyphrases' already exists in node 'a06c3d'. Skipping!
# Property 'keyphrases' already exists in node '5f34f5'. Skipping!
# Applying KeyphrasesExtractor:  87%|████████▋ | 586/673 [03:33<00:13,  6.31it/s]Property 'keyphrases' already exists in node '27d291'. Skipping!
# Property 'keyphrases' already exists in node '65c19b'. Skipping!
# Applying KeyphrasesExtractor:  87%|████████▋ | 588/673 [03:33<00:13,  6.32it/s]Property 'keyphrases' already exists in node '8dbcfa'. Skipping!
# Applying KeyphrasesExtractor:  88%|████████▊ | 589/673 [03:34<00:26,  3.22it/s]Property 'keyphrases' already exists in node '934965'. Skipping!
# Applying KeyphrasesExtractor:  88%|████████▊ | 590/673 [03:34<00:25,  3.25it/s]Property 'keyphrases' already exists in node '069e96'. Skipping!
# Property 'keyphrases' already exists in node 'd76acc'. Skipping!
# Applying KeyphrasesExtractor:  88%|████████▊ | 592/673 [03:35<00:17,  4.60it/s]Property 'keyphrases' already exists in node '23b11a'. Skipping!
# Applying KeyphrasesExtractor:  88%|████████▊ | 593/673 [03:35<00:18,  4.29it/s]Property 'keyphrases' already exists in node 'defebf'. Skipping!
# Applying KeyphrasesExtractor:  88%|████████▊ | 594/673 [03:36<00:29,  2.72it/s]Property 'keyphrases' already exists in node '07e773'. Skipping!
# Applying KeyphrasesExtractor:  88%|████████▊ | 595/673 [03:36<00:37,  2.11it/s]Property 'keyphrases' already exists in node '9a70ed'. Skipping!
# Applying KeyphrasesExtractor:  89%|████████▊ | 596/673 [03:37<00:34,  2.24it/s]Property 'keyphrases' already exists in node 'af3143'. Skipping!
# Applying KeyphrasesExtractor:  89%|████████▊ | 597/673 [03:37<00:30,  2.50it/s]Property 'keyphrases' already exists in node '89359d'. Skipping!
# Applying KeyphrasesExtractor:  89%|████████▉ | 598/673 [03:37<00:24,  3.08it/s]Property 'keyphrases' already exists in node '744598'. Skipping!
# Applying KeyphrasesExtractor:  89%|████████▉ | 599/673 [03:37<00:22,  3.26it/s]Property 'keyphrases' already exists in node 'f6c0b6'. Skipping!
# Property 'keyphrases' already exists in node '336ae3'. Skipping!
# Applying KeyphrasesExtractor:  89%|████████▉ | 601/673 [03:38<00:19,  3.65it/s]Property 'keyphrases' already exists in node '6b0db3'. Skipping!
# Property 'keyphrases' already exists in node '4522b1'. Skipping!
# Applying KeyphrasesExtractor:  90%|████████▉ | 603/673 [03:38<00:15,  4.50it/s]Property 'keyphrases' already exists in node 'e45b03'. Skipping!
# Applying KeyphrasesExtractor:  90%|████████▉ | 604/673 [03:39<00:18,  3.67it/s]Property 'keyphrases' already exists in node '0d679b'. Skipping!
# Applying KeyphrasesExtractor:  90%|████████▉ | 605/673 [03:39<00:20,  3.30it/s]Property 'keyphrases' already exists in node '8448ac'. Skipping!
# Applying KeyphrasesExtractor:  90%|█████████ | 606/673 [03:39<00:20,  3.24it/s]Property 'keyphrases' already exists in node '434322'. Skipping!
# Applying KeyphrasesExtractor:  90%|█████████ | 607/673 [03:40<00:18,  3.55it/s]Property 'keyphrases' already exists in node '6866c3'. Skipping!
# Applying KeyphrasesExtractor:  90%|█████████ | 608/673 [03:40<00:17,  3.78it/s]Property 'keyphrases' already exists in node 'd37659'. Skipping!
# Applying KeyphrasesExtractor:  90%|█████████ | 609/673 [03:41<00:27,  2.32it/s]Property 'keyphrases' already exists in node '6ba493'. Skipping!
# Property 'keyphrases' already exists in node '2bbc3d'. Skipping!
# Applying KeyphrasesExtractor:  91%|█████████ | 611/673 [03:41<00:19,  3.23it/s]Property 'keyphrases' already exists in node 'e4ee11'. Skipping!
# Applying KeyphrasesExtractor:  91%|█████████ | 612/673 [03:42<00:34,  1.76it/s]Property 'keyphrases' already exists in node 'd1b142'. Skipping!
# Applying KeyphrasesExtractor:  91%|█████████ | 613/673 [03:43<00:36,  1.64it/s]Property 'keyphrases' already exists in node '6a6b79'. Skipping!
# Applying KeyphrasesExtractor:  91%|█████████ | 614/673 [03:43<00:28,  2.10it/s]Property 'keyphrases' already exists in node 'fca3fe'. Skipping!
# Property 'keyphrases' already exists in node '8a6597'. Skipping!
# Applying KeyphrasesExtractor:  92%|█████████▏| 616/673 [03:43<00:17,  3.19it/s]Property 'keyphrases' already exists in node '53f77d'. Skipping!
# Property 'keyphrases' already exists in node '08ccc0'. Skipping!
# Applying KeyphrasesExtractor:  92%|█████████▏| 618/673 [03:45<00:23,  2.34it/s]unable to apply transformation: Invalid json output: https://edu.nl/64gpk\nedu.nl/64gpk
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  92%|█████████▏| 619/673 [03:45<00:22,  2.40it/s]Property 'keyphrases' already exists in node 'f8e61b'. Skipping!
# Applying KeyphrasesExtractor:  92%|█████████▏| 620/673 [03:45<00:20,  2.63it/s]Property 'keyphrases' already exists in node 'fa62ba'. Skipping!
# Applying KeyphrasesExtractor:  92%|█████████▏| 621/673 [03:46<00:27,  1.91it/s]Property 'keyphrases' already exists in node '8533a5'. Skipping!
# Applying KeyphrasesExtractor:  92%|█████████▏| 622/673 [03:47<00:30,  1.70it/s]Property 'keyphrases' already exists in node '0b3b94'. Skipping!
# Property 'keyphrases' already exists in node 'c155f2'. Skipping!
# Applying KeyphrasesExtractor:  93%|█████████▎| 624/673 [03:49<00:32,  1.51it/s]Property 'keyphrases' already exists in node 'd7d481'. Skipping!
# Applying KeyphrasesExtractor:  93%|█████████▎| 625/673 [03:49<00:31,  1.54it/s]Property 'keyphrases' already exists in node '91eed9'. Skipping!
# Applying KeyphrasesExtractor:  93%|█████████▎| 626/673 [03:50<00:34,  1.37it/s]Property 'keyphrases' already exists in node '62e04f'. Skipping!
# Applying KeyphrasesExtractor:  93%|█████████▎| 627/673 [03:51<00:34,  1.35it/s]Property 'keyphrases' already exists in node 'eb1532'. Skipping!
# Property 'keyphrases' already exists in node 'fccc48'. Skipping!
# Applying KeyphrasesExtractor:  93%|█████████▎| 629/673 [03:51<00:21,  2.06it/s]Property 'keyphrases' already exists in node '1edf17'. Skipping!
# Applying KeyphrasesExtractor:  94%|█████████▎| 630/673 [03:52<00:23,  1.84it/s]Property 'keyphrases' already exists in node 'cb578e'. Skipping!
# Applying KeyphrasesExtractor:  94%|█████████▍| 631/673 [03:52<00:19,  2.15it/s]Property 'keyphrases' already exists in node 'dac497'. Skipping!
# Applying KeyphrasesExtractor:  94%|█████████▍| 632/673 [03:53<00:20,  2.02it/s]unable to apply transformation: Invalid json output: Simple model of an artificial neuron
# https://medium.com/@cprasenjit32/perceptron-a-simple-yet-mighty-machine-learning-algorithm-9ff6b7d86a71
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Property 'keyphrases' already exists in node '1ea67d'. Skipping!
# Applying KeyphrasesExtractor:  94%|█████████▍| 634/673 [03:53<00:13,  2.80it/s]Property 'keyphrases' already exists in node 'ebc9bd'. Skipping!
# Applying KeyphrasesExtractor:  94%|█████████▍| 635/673 [03:53<00:13,  2.80it/s]Property 'keyphrases' already exists in node '538afe'. Skipping!
# Applying KeyphrasesExtractor:  95%|█████████▍| 636/673 [03:54<00:14,  2.51it/s]Property 'keyphrases' already exists in node 'bf7f97'. Skipping!
# Applying KeyphrasesExtractor:  95%|█████████▍| 637/673 [03:54<00:15,  2.28it/s]Property 'keyphrases' already exists in node '6462e5'. Skipping!
# Property 'keyphrases' already exists in node '4b6d4a'. Skipping!
# Applying KeyphrasesExtractor:  95%|█████████▍| 639/673 [03:55<00:15,  2.14it/s]Property 'keyphrases' already exists in node '101291'. Skipping!
# Property 'keyphrases' already exists in node '7a17ce'. Skipping!
# Applying KeyphrasesExtractor:  95%|█████████▌| 641/673 [03:56<00:10,  3.18it/s]Property 'keyphrases' already exists in node 'cf274c'. Skipping!
# Applying KeyphrasesExtractor:  95%|█████████▌| 642/673 [03:56<00:11,  2.80it/s]Property 'keyphrases' already exists in node '3cd171'. Skipping!
# Applying KeyphrasesExtractor:  96%|█████████▌| 643/673 [03:56<00:09,  3.04it/s]Property 'keyphrases' already exists in node '971a47'. Skipping!
# Applying KeyphrasesExtractor:  96%|█████████▌| 644/673 [03:57<00:09,  2.98it/s]Property 'keyphrases' already exists in node 'c10ebe'. Skipping!
# Applying KeyphrasesExtractor:  96%|█████████▌| 645/673 [03:57<00:08,  3.29it/s]Property 'keyphrases' already exists in node '143bff'. Skipping!
# Property 'keyphrases' already exists in node 'e7da12'. Skipping!
# Applying KeyphrasesExtractor:  96%|█████████▌| 647/673 [03:57<00:07,  3.40it/s]Property 'keyphrases' already exists in node '1a1ed6'. Skipping!
# Applying KeyphrasesExtractor:  96%|█████████▋| 648/673 [03:58<00:06,  3.82it/s]Property 'keyphrases' already exists in node 'cadad9'. Skipping!
# Applying KeyphrasesExtractor:  96%|█████████▋| 649/673 [03:58<00:06,  3.72it/s]Property 'keyphrases' already exists in node 'ad8996'. Skipping!
# Applying KeyphrasesExtractor:  97%|█████████▋| 650/673 [03:59<00:08,  2.58it/s]Property 'keyphrases' already exists in node 'e57763'. Skipping!
# Property 'keyphrases' already exists in node '2cf231'. Skipping!
# Property 'keyphrases' already exists in node '3b408b'. Skipping!
# Applying KeyphrasesExtractor:  97%|█████████▋| 653/673 [03:59<00:05,  3.62it/s]Property 'keyphrases' already exists in node '550d14'. Skipping!
# Applying KeyphrasesExtractor:  97%|█████████▋| 654/673 [03:59<00:04,  3.89it/s]Property 'keyphrases' already exists in node '1e09e1'. Skipping!
# Property 'keyphrases' already exists in node '13e5d0'. Skipping!
# Applying KeyphrasesExtractor:  97%|█████████▋| 656/673 [04:00<00:03,  5.32it/s]Property 'keyphrases' already exists in node 'e4a064'. Skipping!
# Applying KeyphrasesExtractor:  98%|█████████▊| 657/673 [04:00<00:02,  5.64it/s]Property 'keyphrases' already exists in node 'b4059e'. Skipping!
# Applying KeyphrasesExtractor:  98%|█████████▊| 658/673 [04:00<00:02,  5.14it/s]Property 'keyphrases' already exists in node 'eaf984'. Skipping!
# Applying KeyphrasesExtractor:  98%|█████████▊| 659/673 [04:00<00:03,  4.49it/s]Property 'keyphrases' already exists in node '4739fa'. Skipping!
# Applying KeyphrasesExtractor:  98%|█████████▊| 660/673 [04:01<00:04,  2.72it/s]Property 'keyphrases' already exists in node '5919b1'. Skipping!
# Property 'keyphrases' already exists in node '34af1e'. Skipping!
# Property 'keyphrases' already exists in node '337c2c'. Skipping!
# Applying KeyphrasesExtractor:  99%|█████████▊| 663/673 [04:02<00:03,  3.30it/s]Property 'keyphrases' already exists in node 'b709cb'. Skipping!
# Applying KeyphrasesExtractor:  99%|█████████▊| 664/673 [04:02<00:02,  3.16it/s]Property 'keyphrases' already exists in node '5bec21'. Skipping!
# Applying KeyphrasesExtractor:  99%|█████████▉| 665/673 [04:02<00:02,  3.58it/s]Property 'keyphrases' already exists in node 'd100d0'. Skipping!
# Applying KeyphrasesExtractor:  99%|█████████▉| 666/673 [04:02<00:01,  4.06it/s]Property 'keyphrases' already exists in node '47ec40'. Skipping!
# Applying KeyphrasesExtractor:  99%|█████████▉| 667/673 [04:04<00:02,  2.13it/s]Property 'keyphrases' already exists in node 'd6b1ec'. Skipping!
# Applying KeyphrasesExtractor:  99%|█████████▉| 668/673 [04:04<00:02,  2.32it/s]Property 'keyphrases' already exists in node '86c723'. Skipping!
# Property 'keyphrases' already exists in node 'ea3a94'. Skipping!
# Applying KeyphrasesExtractor: 100%|█████████▉| 670/673 [04:05<00:01,  2.51it/s]Property 'keyphrases' already exists in node '310801'. Skipping!
# Applying KeyphrasesExtractor: 100%|█████████▉| 671/673 [04:05<00:00,  2.31it/s]Property 'keyphrases' already exists in node 'b9d7e1'. Skipping!
# Applying KeyphrasesExtractor: 100%|█████████▉| 672/673 [04:07<00:00,  1.20it/s]Property 'keyphrases' already exists in node 'a67bde'. Skipping!
# Knowledge graph now has 673 nodes after transforms.

# %% [markdown]
# ## Generate the single-hop dataset based on SSE Course Slides

# %%
testset_size = 50
output_file = "sse_single_hop_testset.csv"

# Step 7: Generate testset
print("Generating testset...")
generator = TestsetGenerator(
    llm=generator_llm,
    embedding_model=generator_embeddings,
    knowledge_graph=kg,
    persona_list=personas,
)

testset = generator.generate(testset_size=testset_size, query_distribution=query_distribution)

# Save to CSV
print(f"Saving {len(testset)} generated test samples to {output_file}...")
testset.to_pandas().to_csv(output_file, index=False)
print("Done!")
# Out:
# Generating testset...
# Generating Scenarios: 100%|██████████| 2/2 [02:30<00:00, 75.38s/it]
# Generating Samples: 100%|██████████| 50/50 [00:21<00:00,  2.37it/s]
# Saving 50 generated test samples to sse_single_hop_testset.csv...
# Done!

# %%
testset.to_pandas()
# Out:
#                                            user_input  \
# 0   What is the focus of the '1. Intro to Sustaina...
# 1                  What is environmental-responsible?
# 2           What is Sustainable Software Engineering?
# 3           What is Sustainable Software Engineering?
# 4   What role does the social aspect play in softw...
# 5   What economical factors are important in softw...
# 6   What is the relevance of Bus factor to softwar...
# 7                                  What is Democrazy?
# 8   What is the relationship between Environmental...
# 9   Why is Green Software important for computer s...
# 10  Why does economical sustainability prioritzes ...
# 11  What does 'Green Washing' mean in the context ...
# 12  How did the software in the VW scandal help ch...
# 13  What are the methods or approaches that can be...
# 14       What are some examples of green procurement?
# 15  Why is the smartphone lifetime being extended ...
# 16  What companies are called carbon-free giants a...
# 17  What is the Rebound effect and how does it aff...
# 18  Is sustainability considered an ethical issue,...
# 19  Why should climate action be neutral towards p...
# 20  Why is it important to focus on sustainability...
# 21  What is the format of the class regarding Lect...
# 22  Why do we have a mix of content and discussion...
# 23           What is the content of the course about?
# 24  What are the objectives and approach of Projec...
# 25                    Who is E.BarbaRoque@tudelft.nl?
# 26                            What is Sustainable SE?
# 27  What percentage of the electricity consumed wo...
# 28            What is the purpose of XKCD comic 1007?
# 29  As a professional developer focused on green s...
# 30                       What is Sofware Engineering?
# 31  What is Sustainable Software Engineering and h...
# 32  What are the different dimensions of software ...
# 33  What are the main things that a company should...
# 34  As a developer focused on green software pract...
# 35  What role does career development play in indi...
# 36  What are the factors that erode trust in socie...
# 37  Why is it important for software to have minim...
# 38          Why are limited power resorces important?
# 39  What is the sustainability dimention in softwa...
# 40  How does environmental sustainability play a r...
# 41            Why is green perceived as eco-friendly?
# 42  Can you provide an example of greenwashing in ...
# 43  How can we drive sustainability in the softwar...
# 44           Why developers work for green companies?
# 45  What is the purpose of the website https://rep...
# 46  Why software for sustainability is not covered...
# 47  What are the goals of the companies referred t...
# 48                      Is Chat GPT energy efficient?
# 49  Why are the poorest countries most affected by...
#
#                                    reference_contexts  \
# 0   [1. Intro to Sustainable SE \n2. Intro to the ...
# 1   [Buzz words\n• Eco-friendly\n• Climate change,...
# 2   [https://www.menti.com/uns9d89kzn\nWhat is Sus...
# 3   [Sustainable Software \nEngineering is…\n7\n…t...
# 4   [8\nEconomical\nSocial\nTechnical\nIndividual\...
# 5   [Economical\n• Focused on assets, capital and ...
# 6   [Technical\n• Longevity of information, system...
# 7   [Social\n• concerned with societal communities...
# 8   [Environmental Sustainability\n• the branch of...
# 9   [Green Software\n• Sustainability and energy e...
# 10  [Economical sustainability tops the environmen...
# 11  [Green Washing\n• Deceptively use marketing te...
# 12  [The VW scandal\nGreenwashing\n• Used software...
# 13  [How can we drive sustainability \nin the SE i...
# 14  [Green Procurement\n• Customers decide on prov...
# 15  [Sustainability via compliance\n• EU wants to ...
# 16  [Carbon-free giants\n• Google, Microsoft, Meta...
# 17  [Rebound effect*\n• Energy consumption decreas...
# 18  [Is sustainability an
# \nethical issue?\n• Clim...
# 19  [Morality ≠ Moralising\n• We should not use cl...
# 20  [Why?\n• Throughout your career you might:\n• ...
# 21  [Format of classes\n• In-person.\n• Collegeram...
# 22  [Format of classes\n• There’s no exam in this ...
# 23  [https://luiscruz.github.io/course_sustainable...
# 24  [Project 1\n• Goal: Measure the energy consump...
# 25  [Carolin Brandt \nC.E.Brandt@tudelft.nl \nLuís...
# 26  [1. Intro to Sustainable SE \n2. Intro to the ...
# 27  [of the electricity consumed worldwide \nby 20...
# 28                        [4\nhttps://xkcd.com/1007/]
# 29  [Buzz words\n• Eco-friendly\n• Climate change,...
# 30  [https://www.menti.com/uns9d89kzn\nWhat is Sus...
# 31  [Sustainable Software \nEngineering is…\n7\n…t...
# 32  [8\nEconomical\nSocial\nTechnical\nIndividual\...
# 33  [Economical\n• Focused on assets, capital and ...
# 34  [Technical\n• Longevity of information, system...
# 35  [Individual\n• Well-being of the individuals i...
# 36  [Social\n• concerned with societal communities...
# 37  [Environmental Sustainability\n• the branch of...
# 38  [Green Software\n• Sustainability and energy e...
# 39  [https://www.menti.com/uns9d89kzn\nWhat is the...
# 40  [Economical sustainability tops the environmen...
# 41  [Green Washing\n• Deceptively use marketing te...
# 42  [The VW scandal\nGreenwashing\n• Used software...
# 43  [How can we drive sustainability \nin the SE i...
# 44  [Green Procurement\n• Customers decide on prov...
# 45  [Sustainability via compliance\n• EU wants to ...
# 46  [Software for Sustainability \n• We are not co...
# 47  [Carbon-free giants\n• Google, Microsoft, Meta...
# 48  [Rebound effect*\n• Energy consumption decreas...
# 49  [Is sustainability an
# \nethical issue?\n• Clim...
#
#                                             reference  \
# 0   The '1. Intro to Sustainable SE' section serve...
# 1            Environmental-responsible is a buzzword.
# 2   Sustainable Software Engineering refers to the...
# 3   Sustainable Software Engineering is the discip...
# 4   The social aspect is one of the key dimensions...
# 5   Economical factors include assets, capital, ad...
# 6   Bus-factor is a relevant consideration in soft...
# 7   Democracy is a societal factor that contribute...
# 8   Environmental Sustainability in software engin...
# 9   Green Software is important because it focuses...
# 10  Economical sustainability is crucial for the s...
# 11  Green Washing refers to the practice of decept...
# 12  The software in the VW scandal was used to che...
# 13  Driving sustainability in the software enginee...
# 14  Examples of green procurement include customer...
# 15  Extending the smartphone lifetime to 7 years i...
# 16  Google, Microsoft, and Meta/Facebook are calle...
# 17  The Rebound effect, also known as Jevons Parad...
# 18  Yes, sustainability is considered an ethical i...
# 19  Climate action should be neutral towards polit...
# 20  Sustainability is important in various career ...
# 21  The class format includes in-person sessions, ...
# 22  The mix of content and discussion in class is ...
# 23  The content of the course is available at the ...
# 24  Project 1 is designed to measure the energy co...
# 25    E.BarbaRoque@tudelft.nl is Enrique Barba Roque.
# 26  Sustainable SE is the focus of the course, as ...
# 27  By 2040, 14% of the electricity consumed world...
# 28  XKCD comic 1007 is available at https://xkcd.c...
# 29  The term 'adaption' is mentioned in the contex...
# 30  The context provided discusses Sustainable Sof...
# 31  Sustainable Software Engineering is the discip...
# 32  Software engineering encompasses several dimen...
# 33  When managing assets and capital, a company sh...
# 34  Ensuring that a system 'does it scale?' is a k...
# 35  Career development is a key component of indiv...
# 36  Factors that erode trust in societal communiti...
# 37  Software that has minimal impact on the enviro...
# 38  Smartphones, smart wearables, IoT devices, etc...
# 39  The question is about identifying the sustaina...
# 40  Environmental sustainability has become a key ...
# 41                Green is perceived as eco-friendly.
# 42  An example of greenwashing in software is the ...
# 43  Driving sustainability in the software enginee...
# 44  Developers work for green companies because gr...
# 45  The website https://repair.eu is associated wi...
# 46  Software for sustainability is not covered in ...
# 47  The companies referred to as 'Carbon-free gian...
# 48    Yes, Chat GPT is described as energy-efficient.
# 49  The poorest countries are more likely to be af...
#
#                         synthesizer_name
# 0   single_hop_specifc_query_synthesizer
# 1   single_hop_specifc_query_synthesizer
# 2   single_hop_specifc_query_synthesizer
# 3   single_hop_specifc_query_synthesizer
# 4   single_hop_specifc_query_synthesizer
# 5   single_hop_specifc_query_synthesizer
# 6   single_hop_specifc_query_synthesizer
# 7   single_hop_specifc_query_synthesizer
# 8   single_hop_specifc_query_synthesizer
# 9   single_hop_specifc_query_synthesizer
# 10  single_hop_specifc_query_synthesizer
# 11  single_hop_specifc_query_synthesizer
# 12  single_hop_specifc_query_synthesizer
# 13  single_hop_specifc_query_synthesizer
# 14  single_hop_specifc_query_synthesizer
# 15  single_hop_specifc_query_synthesizer
# 16  single_hop_specifc_query_synthesizer
# 17  single_hop_specifc_query_synthesizer
# 18  single_hop_specifc_query_synthesizer
# 19  single_hop_specifc_query_synthesizer
# 20  single_hop_specifc_query_synthesizer
# 21  single_hop_specifc_query_synthesizer
# 22  single_hop_specifc_query_synthesizer
# 23  single_hop_specifc_query_synthesizer
# 24  single_hop_specifc_query_synthesizer
# 25  single_hop_specifc_query_synthesizer
# 26  single_hop_specifc_query_synthesizer
# 27  single_hop_specifc_query_synthesizer
# 28  single_hop_specifc_query_synthesizer
# 29  single_hop_specifc_query_synthesizer
# 30  single_hop_specifc_query_synthesizer
# 31  single_hop_specifc_query_synthesizer
# 32  single_hop_specifc_query_synthesizer
# 33  single_hop_specifc_query_synthesizer
# 34  single_hop_specifc_query_synthesizer
# 35  single_hop_specifc_query_synthesizer
# 36  single_hop_specifc_query_synthesizer
# 37  single_hop_specifc_query_synthesizer
# 38  single_hop_specifc_query_synthesizer
# 39  single_hop_specifc_query_synthesizer
# 40  single_hop_specifc_query_synthesizer
# 41  single_hop_specifc_query_synthesizer
# 42  single_hop_specifc_query_synthesizer
# 43  single_hop_specifc_query_synthesizer
# 44  single_hop_specifc_query_synthesizer
# 45  single_hop_specifc_query_synthesizer
# 46  single_hop_specifc_query_synthesizer
# 47  single_hop_specifc_query_synthesizer
# 48  single_hop_specifc_query_synthesizer
# 49  single_hop_specifc_query_synthesizer

# %% [markdown]
# ## Setup for multi-hop testset generation

# %%
scenario_num=5
testset_size=1

# %%
 # Steps 1 - 3: Prepare knowledge graph and models
kg, generator_llm, generator_embeddings = prepare_knowledge_graph(pdf_dir)

# Step 4: Apply transforms
relation_builder = OverlapScoreBuilder(
    property_name="keyphrases",
    new_property_name="overlap_score",
    threshold=0.01,
    distance_threshold=0.9,
)

transforms = [
    HeadlinesExtractor(llm=generator_llm, max_num=10),
    HeadlineSplitter(max_tokens=1000),
    KeyphrasesExtractor(llm=generator_llm, property_name="keyphrases", max_num=10),
    relation_builder
]

apply_transforms(kg, transforms=transforms)
print(f"Knowledge graph now has {len(kg.nodes)} nodes after transforms.")

# Step 5: Configure personas
personas = create_sustainable_se_personas()

@dataclass
class MyMultiHopQuery(MultiHopQuerySynthesizer):

    theme_persona_matching_prompt = ThemesPersonasMatchingPrompt()

    async def _generate_scenarios(
        self,
        n: int,
        knowledge_graph,
        persona_list,
        callbacks,
    ) -> t.List[MultiHopScenario]:

        # query and get (node_a, rel, node_b) to create multi-hop queries
        results = kg.find_two_nodes_single_rel(
            relationship_condition=lambda rel: (
                True if rel.type == "keyphrases_overlap" else False
            )
        )

        num_sample_per_triplet = max(1, n // len(results))

        scenarios = []
        for triplet in results:
            if len(scenarios) < n:
                node_a, node_b = triplet[0], triplet[-1]
                overlapped_keywords = triplet[1].properties["overlapped_items"]
                if overlapped_keywords:

                    # match the keyword with a persona for query creation
                    themes = list(dict(overlapped_keywords).keys())
                    prompt_input = ThemesPersonasInput(
                        themes=themes, personas=persona_list
                    )
                    persona_concepts = (
                        await self.theme_persona_matching_prompt.generate(
                            data=prompt_input, llm=self.llm, callbacks=callbacks
                        )
                    )

                    overlapped_keywords = [list(item) for item in overlapped_keywords]

                    # prepare and sample possible combinations
                    base_scenarios = self.prepare_combinations(
                        [node_a, node_b],
                        overlapped_keywords,
                        personas=persona_list,
                        persona_item_mapping=persona_concepts.mapping,
                        property_name="keyphrases",
                    )

                    # get number of required samples from this triplet
                    base_scenarios = self.sample_diverse_combinations(
                        base_scenarios, num_sample_per_triplet
                    )

                    scenarios.extend(base_scenarios)

        return scenarios
    
query = MyMultiHopQuery(llm=generator_llm)
# Out:
# Ignoring wrong pointing object 64 0 (offset 0)
# Ignoring wrong pointing object 70 0 (offset 0)
# Ignoring wrong pointing object 192 0 (offset 0)
# Ignoring wrong pointing object 319 0 (offset 0)
# Ignoring wrong pointing object 320 0 (offset 0)
# Loading PDF documents...
# Loading 01_intro.pdf...
# Ignoring wrong pointing object 90 0 (offset 0)
# Ignoring wrong pointing object 206 0 (offset 0)
# Ignoring wrong pointing object 207 0 (offset 0)
# Ignoring wrong pointing object 32 0 (offset 0)
# Ignoring wrong pointing object 66 0 (offset 0)
# Ignoring wrong pointing object 123 0 (offset 0)
#   Added 42 pages from 01_intro.pdf
# Loading 02_lab_measuring_energy.pdf...
#   Added 27 pages from 02_lab_measuring_energy.pdf
# Loading 03_scientific_guide.pdf...
# Ignoring wrong pointing object 46 0 (offset 0)
# Ignoring wrong pointing object 72 0 (offset 0)
# Ignoring wrong pointing object 142 0 (offset 0)
# Ignoring wrong pointing object 242 0 (offset 0)
# Ignoring wrong pointing object 243 0 (offset 0)
#   Added 39 pages from 03_scientific_guide.pdf
# Loading 05_metrics.pdf...
# Ignoring wrong pointing object 174 0 (offset 0)
# Ignoring wrong pointing object 234 0 (offset 0)
# Ignoring wrong pointing object 243 0 (offset 0)
# Ignoring wrong pointing object 355 0 (offset 0)
# Ignoring wrong pointing object 386 0 (offset 0)
# Ignoring wrong pointing object 388 0 (offset 0)
# Ignoring wrong pointing object 398 0 (offset 0)
# Ignoring wrong pointing object 400 0 (offset 0)
# Ignoring wrong pointing object 407 0 (offset 0)
# Ignoring wrong pointing object 409 0 (offset 0)
# Ignoring wrong pointing object 415 0 (offset 0)
# Ignoring wrong pointing object 417 0 (offset 0)
# Ignoring wrong pointing object 423 0 (offset 0)
# Ignoring wrong pointing object 425 0 (offset 0)
# Ignoring wrong pointing object 431 0 (offset 0)
# Ignoring wrong pointing object 433 0 (offset 0)
# Ignoring wrong pointing object 489 0 (offset 0)
# Ignoring wrong pointing object 491 0 (offset 0)
# Ignoring wrong pointing object 493 0 (offset 0)
# Ignoring wrong pointing object 495 0 (offset 0)
# Ignoring wrong pointing object 497 0 (offset 0)
# Ignoring wrong pointing object 499 0 (offset 0)
# Ignoring wrong pointing object 501 0 (offset 0)
# Ignoring wrong pointing object 503 0 (offset 0)
# Ignoring wrong pointing object 505 0 (offset 0)
# Ignoring wrong pointing object 507 0 (offset 0)
# Ignoring wrong pointing object 509 0 (offset 0)
# Ignoring wrong pointing object 511 0 (offset 0)
# Ignoring wrong pointing object 649 0 (offset 0)
# Ignoring wrong pointing object 651 0 (offset 0)
# Ignoring wrong pointing object 653 0 (offset 0)
# Ignoring wrong pointing object 655 0 (offset 0)
# Ignoring wrong pointing object 657 0 (offset 0)
# Ignoring wrong pointing object 659 0 (offset 0)
# Ignoring wrong pointing object 661 0 (offset 0)
# Ignoring wrong pointing object 663 0 (offset 0)
# Ignoring wrong pointing object 665 0 (offset 0)
# Ignoring wrong pointing object 667 0 (offset 0)
# Ignoring wrong pointing object 669 0 (offset 0)
# Ignoring wrong pointing object 671 0 (offset 0)
# Ignoring wrong pointing object 726 0 (offset 0)
# Ignoring wrong pointing object 727 0 (offset 0)
#   Added 38 pages from 05_metrics.pdf
# Loading 07_green_software_research.pdf...
# Ignoring wrong pointing object 72 0 (offset 0)
# Ignoring wrong pointing object 221 0 (offset 0)
# Ignoring wrong pointing object 241 0 (offset 0)
# Ignoring wrong pointing object 247 0 (offset 0)
# Ignoring wrong pointing object 248 0 (offset 0)
# Ignoring wrong pointing object 249 0 (offset 0)
# Ignoring wrong pointing object 250 0 (offset 0)
# Ignoring wrong pointing object 251 0 (offset 0)
# Ignoring wrong pointing object 252 0 (offset 0)
# Ignoring wrong pointing object 253 0 (offset 0)
# Ignoring wrong pointing object 254 0 (offset 0)
# Ignoring wrong pointing object 255 0 (offset 0)
# Ignoring wrong pointing object 256 0 (offset 0)
# Ignoring wrong pointing object 257 0 (offset 0)
# Ignoring wrong pointing object 258 0 (offset 0)
# Ignoring wrong pointing object 335 0 (offset 0)
# Ignoring wrong pointing object 336 0 (offset 0)
#   Added 52 pages from 07_green_software_research.pdf
# Loading 08_green_ai.pdf...
# Ignoring wrong pointing object 62 0 (offset 0)
# Ignoring wrong pointing object 105 0 (offset 0)
# Ignoring wrong pointing object 108 0 (offset 0)
# Ignoring wrong pointing object 110 0 (offset 0)
# Ignoring wrong pointing object 112 0 (offset 0)
# Ignoring wrong pointing object 115 0 (offset 0)
# Ignoring wrong pointing object 116 0 (offset 0)
# Ignoring wrong pointing object 118 0 (offset 0)
# Ignoring wrong pointing object 122 0 (offset 0)
# Ignoring wrong pointing object 126 0 (offset 0)
# Ignoring wrong pointing object 128 0 (offset 0)
# Ignoring wrong pointing object 130 0 (offset 0)
# Ignoring wrong pointing object 132 0 (offset 0)
# Ignoring wrong pointing object 134 0 (offset 0)
# Ignoring wrong pointing object 136 0 (offset 0)
# Ignoring wrong pointing object 138 0 (offset 0)
# Ignoring wrong pointing object 140 0 (offset 0)
# Ignoring wrong pointing object 142 0 (offset 0)
# Ignoring wrong pointing object 144 0 (offset 0)
# Ignoring wrong pointing object 146 0 (offset 0)
# Ignoring wrong pointing object 151 0 (offset 0)
# Ignoring wrong pointing object 155 0 (offset 0)
# Ignoring wrong pointing object 161 0 (offset 0)
# Ignoring wrong pointing object 165 0 (offset 0)
# Ignoring wrong pointing object 178 0 (offset 0)
# Ignoring wrong pointing object 189 0 (offset 0)
# Ignoring wrong pointing object 282 0 (offset 0)
# Ignoring wrong pointing object 283 0 (offset 0)
#   Added 47 pages from 08_green_ai.pdf
# Loading 10_project2.pdf...
#   Added 30 pages from 10_project2.pdf
# Loading 11_SusSE Lecture - Neuromorphic computing 2025.pdf...
#   Added 65 pages from 11_SusSE Lecture - Neuromorphic computing 2025.pdf
# Loaded 340 document chunks.
# Setting up LLM and embedding models...
# Creating knowledge graph...
# Created initial knowledge graph with 340 nodes.
# Applying HeadlinesExtractor:   5%|▌         | 18/340 [00:07<01:20,  3.98it/s]unable to apply transformation: Failed to parse Headlines from completion 4. Got: 1 validation error for Headlines
#   Input should be a valid dictionary or instance of Headlines [type=model_type, input_value=4, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.10/v/model_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying HeadlinesExtractor:  12%|█▏        | 42/340 [00:16<01:51,  2.66it/s]unable to apply transformation: Failed to parse Headlines from completion 32. Got: 1 validation error for Headlines
#   Input should be a valid dictionary or instance of Headlines [type=model_type, input_value=32, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.10/v/model_type
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying HeadlinesExtractor:  32%|███▏      | 110/340 [00:32<01:01,  3.73it/s]unable to apply transformation: Invalid json output: Problems in the Computer Language Benchmarks Game
# 34
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying HeadlinesExtractor:  69%|██████▉   | 236/340 [01:09<00:25,  4.15it/s]unable to apply transformation: Invalid json output: DeepSeekMoE
# 32
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying HeadlinesExtractor:  71%|███████   | 241/340 [01:10<00:26,  3.81it/s]unable to apply transformation: The LLM generation was not completed. Please increase the max_tokens and try again.
# Applying HeadlineSplitter:   0%|          | 0/340 [00:00<?, ?it/s]            unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# unable to apply transformation: 'headlines' property not found in this node
# Applying KeyphrasesExtractor:  20%|██        | 137/675 [00:53<03:07,  2.86it/s]unable to apply transformation: Invalid json output: Carbon\nEnergy
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  21%|██▏       | 144/675 [00:54<01:38,  5.38it/s]unable to apply transformation: Invalid json output: • Carbon emissions
# ✅
# • How do we go from energy consumption to carbon consumption?
# 27
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  24%|██▍       | 165/675 [01:02<04:04,  2.08it/s]unable to apply transformation: Invalid json output: Marginal Carbon Intensity
# • Increase or decrease in carbon emissions in the electrical grid, in response
# to an inﬁnitesimal increase/decrease in power demand/supply.
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  29%|██▊       | 193/675 [01:12<03:54,  2.05it/s]unable to apply transformation: The LLM generation was not completed. Please increase the max_tokens and try again.
# Applying KeyphrasesExtractor:  38%|███▊      | 254/675 [01:34<02:19,  3.03it/s]unable to apply transformation: Invalid json output: DeepSeekMoE
# 30
# Preprint at ArXiv, 2024 https://arxiv.org/pdf/
# 2401.06066
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  41%|████      | 276/675 [01:47<04:25,  1.50it/s]unable to apply transformation: The LLM generation was not completed. Please increase the max_tokens and try again.
# Applying KeyphrasesExtractor:  42%|████▏     | 282/675 [01:50<03:05,  2.12it/s]unable to apply transformation: Invalid json output: Simple model of an artificial neuron
# https://medium.com/@cprasenjit32/perceptron-a-simple-yet-mighty-machine-learning-algorithm-9ff6b7d86a71
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  43%|████▎     | 291/675 [01:53<02:00,  3.19it/s]unable to apply transformation: Invalid json output: https://edu.nl/64gpk
# edu.nl/64gpk
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE
# Applying KeyphrasesExtractor:  50%|████▉     | 335/675 [02:09<03:02,  1.86it/s]Property 'keyphrases' already exists in node '27570b'. Skipping!
# Applying KeyphrasesExtractor:  50%|████▉     | 336/675 [02:11<05:07,  1.10it/s]Property 'keyphrases' already exists in node '1d4ead'. Skipping!
# Property 'keyphrases' already exists in node 'cca8bc'. Skipping!
# Applying KeyphrasesExtractor:  50%|█████     | 340/675 [02:13<03:56,  1.42it/s]Property 'keyphrases' already exists in node 'f08d56'. Skipping!
# Applying KeyphrasesExtractor:  51%|█████     | 341/675 [02:15<05:03,  1.10it/s]Property 'keyphrases' already exists in node 'cb098a'. Skipping!
# Applying KeyphrasesExtractor:  51%|█████     | 342/675 [02:15<04:05,  1.36it/s]Property 'keyphrases' already exists in node '5e653f'. Skipping!
# Applying KeyphrasesExtractor:  51%|█████     | 343/675 [02:15<03:46,  1.46it/s]Property 'keyphrases' already exists in node '480ad9'. Skipping!
# Applying KeyphrasesExtractor:  51%|█████     | 344/675 [02:16<02:54,  1.90it/s]Property 'keyphrases' already exists in node '3b8b04'. Skipping!
# Applying KeyphrasesExtractor:  51%|█████     | 345/675 [02:16<03:18,  1.66it/s]Property 'keyphrases' already exists in node 'a963ea'. Skipping!
# Applying KeyphrasesExtractor:  51%|█████▏    | 346/675 [02:16<02:38,  2.08it/s]Property 'keyphrases' already exists in node 'f71933'. Skipping!
# Applying KeyphrasesExtractor:  51%|█████▏    | 347/675 [02:17<02:10,  2.51it/s]Property 'keyphrases' already exists in node 'b0f043'. Skipping!
# unable to apply transformation: The LLM generation was not completed. Please increase the max_tokens and try again.
# Applying KeyphrasesExtractor:  52%|█████▏    | 349/675 [02:17<01:37,  3.35it/s]Property 'keyphrases' already exists in node '8c0920'. Skipping!
# Property 'keyphrases' already exists in node '9227e3'. Skipping!
# Applying KeyphrasesExtractor:  52%|█████▏    | 351/675 [02:17<01:05,  4.92it/s]Property 'keyphrases' already exists in node '2bad38'. Skipping!
# Applying KeyphrasesExtractor:  52%|█████▏    | 353/675 [02:18<01:44,  3.08it/s]Property 'keyphrases' already exists in node '4184ed'. Skipping!
# Applying KeyphrasesExtractor:  53%|█████▎    | 355/675 [02:19<01:34,  3.39it/s]Property 'keyphrases' already exists in node '3523c3'. Skipping!
# Property 'keyphrases' already exists in node '52a8c9'. Skipping!
# Applying KeyphrasesExtractor:  53%|█████▎    | 357/675 [02:19<01:04,  4.92it/s]Property 'keyphrases' already exists in node 'd69c64'. Skipping!
# Applying KeyphrasesExtractor:  53%|█████▎    | 358/675 [02:19<00:58,  5.41it/s]Property 'keyphrases' already exists in node 'be65c9'. Skipping!
# Applying KeyphrasesExtractor:  53%|█████▎    | 359/675 [02:19<01:25,  3.71it/s]Property 'keyphrases' already exists in node '76f989'. Skipping!
# Applying KeyphrasesExtractor:  53%|█████▎    | 360/675 [02:20<01:11,  4.38it/s]Property 'keyphrases' already exists in node 'ad251e'. Skipping!
# Applying KeyphrasesExtractor:  53%|█████▎    | 361/675 [02:20<01:31,  3.42it/s]Property 'keyphrases' already exists in node '4f9316'. Skipping!
# Applying KeyphrasesExtractor:  54%|█████▎    | 362/675 [02:20<01:34,  3.33it/s]Property 'keyphrases' already exists in node '2882c5'. Skipping!
# Applying KeyphrasesExtractor:  54%|█████▍    | 363/675 [02:21<01:34,  3.31it/s]Property 'keyphrases' already exists in node '77db1a'. Skipping!
# Property 'keyphrases' already exists in node 'ea5c04'. Skipping!
# Applying KeyphrasesExtractor:  54%|█████▍    | 365/675 [02:21<00:58,  5.26it/s]Property 'keyphrases' already exists in node 'a5d96b'. Skipping!
# Applying KeyphrasesExtractor:  54%|█████▍    | 366/675 [02:21<01:25,  3.60it/s]Property 'keyphrases' already exists in node 'c1abf5'. Skipping!
# Applying KeyphrasesExtractor:  54%|█████▍    | 367/675 [02:21<01:12,  4.26it/s]Property 'keyphrases' already exists in node 'df23ef'. Skipping!
# Applying KeyphrasesExtractor:  55%|█████▍    | 368/675 [02:22<01:44,  2.95it/s]Property 'keyphrases' already exists in node 'e2b6f8'. Skipping!
# Applying KeyphrasesExtractor:  55%|█████▍    | 369/675 [02:23<02:09,  2.37it/s]Property 'keyphrases' already exists in node '4521ce'. Skipping!
# Applying KeyphrasesExtractor:  55%|█████▍    | 370/675 [02:23<02:00,  2.53it/s]Property 'keyphrases' already exists in node 'dacd86'. Skipping!
# Applying KeyphrasesExtractor:  55%|█████▍    | 371/675 [02:24<02:15,  2.24it/s]Property 'keyphrases' already exists in node '51623d'. Skipping!
# Property 'keyphrases' already exists in node 'b26b79'. Skipping!
# Property 'keyphrases' already exists in node '6a7e44'. Skipping!
# Applying KeyphrasesExtractor:  55%|█████▌    | 374/675 [02:24<01:16,  3.95it/s]Property 'keyphrases' already exists in node '602a23'. Skipping!
# Property 'keyphrases' already exists in node 'c6f6c7'. Skipping!
# Applying KeyphrasesExtractor:  56%|█████▌    | 376/675 [02:25<01:20,  3.72it/s]Property 'keyphrases' already exists in node '1f312c'. Skipping!
# Property 'keyphrases' already exists in node 'a2cb8c'. Skipping!
# Applying KeyphrasesExtractor:  56%|█████▌    | 378/675 [02:25<01:03,  4.70it/s]Property 'keyphrases' already exists in node 'c399e9'. Skipping!
# Applying KeyphrasesExtractor:  56%|█████▌    | 379/675 [02:25<01:34,  3.15it/s]Property 'keyphrases' already exists in node '58779c'. Skipping!
# Applying KeyphrasesExtractor:  56%|█████▋    | 380/675 [02:26<01:26,  3.39it/s]Property 'keyphrases' already exists in node '276d9e'. Skipping!
# Applying KeyphrasesExtractor:  56%|█████▋    | 381/675 [02:26<01:43,  2.84it/s]Property 'keyphrases' already exists in node '82ea5f'. Skipping!
# Applying KeyphrasesExtractor:  57%|█████▋    | 382/675 [02:27<01:59,  2.46it/s]Property 'keyphrases' already exists in node '483c23'. Skipping!
# Applying KeyphrasesExtractor:  57%|█████▋    | 383/675 [02:27<01:38,  2.96it/s]Property 'keyphrases' already exists in node '35f5aa'. Skipping!
# Applying KeyphrasesExtractor:  57%|█████▋    | 384/675 [02:27<01:40,  2.91it/s]Property 'keyphrases' already exists in node '136582'. Skipping!
# Property 'keyphrases' already exists in node 'd958bc'. Skipping!
# Property 'keyphrases' already exists in node '83d7a4'. Skipping!
# Applying KeyphrasesExtractor:  57%|█████▋    | 387/675 [02:28<00:56,  5.10it/s]Property 'keyphrases' already exists in node '6c5390'. Skipping!
# Property 'keyphrases' already exists in node 'd281e2'. Skipping!
# Property 'keyphrases' already exists in node '1cbf26'. Skipping!
# Property 'keyphrases' already exists in node 'a98a52'. Skipping!
# Applying KeyphrasesExtractor:  58%|█████▊    | 391/675 [02:28<00:52,  5.45it/s]Property 'keyphrases' already exists in node '576ef0'. Skipping!
# Property 'keyphrases' already exists in node '1d763c'. Skipping!
# Applying KeyphrasesExtractor:  58%|█████▊    | 393/675 [02:29<00:49,  5.66it/s]Property 'keyphrases' already exists in node '955586'. Skipping!
# Applying KeyphrasesExtractor:  58%|█████▊    | 394/675 [02:29<00:48,  5.75it/s]Property 'keyphrases' already exists in node 'd1438b'. Skipping!
# Applying KeyphrasesExtractor:  59%|█████▊    | 395/675 [02:29<01:09,  4.01it/s]Property 'keyphrases' already exists in node '2348c4'. Skipping!
# Applying KeyphrasesExtractor:  59%|█████▊    | 396/675 [02:30<01:58,  2.35it/s]Property 'keyphrases' already exists in node 'fd1f94'. Skipping!
# Applying KeyphrasesExtractor:  59%|█████▉    | 397/675 [02:31<01:44,  2.66it/s]Property 'keyphrases' already exists in node '4d09c9'. Skipping!
# Property 'keyphrases' already exists in node '918dc9'. Skipping!
# Applying KeyphrasesExtractor:  59%|█████▉    | 399/675 [02:31<01:25,  3.21it/s]Property 'keyphrases' already exists in node '7d3d0d'. Skipping!
# Property 'keyphrases' already exists in node '24b459'. Skipping!
# Applying KeyphrasesExtractor:  59%|█████▉    | 401/675 [02:31<01:13,  3.71it/s]Property 'keyphrases' already exists in node '9ea5f3'. Skipping!
# Applying KeyphrasesExtractor:  60%|█████▉    | 402/675 [02:32<01:33,  2.92it/s]Property 'keyphrases' already exists in node '980583'. Skipping!
# Applying KeyphrasesExtractor:  60%|█████▉    | 403/675 [02:32<01:29,  3.03it/s]Property 'keyphrases' already exists in node '0a84c0'. Skipping!
# Applying KeyphrasesExtractor:  60%|█████▉    | 404/675 [02:32<01:20,  3.35it/s]Property 'keyphrases' already exists in node 'd08db9'. Skipping!
# Applying KeyphrasesExtractor:  60%|██████    | 405/675 [02:33<01:07,  3.97it/s]Property 'keyphrases' already exists in node '19f657'. Skipping!
# Property 'keyphrases' already exists in node '1474df'. Skipping!
# Applying KeyphrasesExtractor:  60%|██████    | 407/675 [02:33<00:53,  5.02it/s]Property 'keyphrases' already exists in node '4ad462'. Skipping!
# Applying KeyphrasesExtractor:  60%|██████    | 408/675 [02:33<01:14,  3.57it/s]Property 'keyphrases' already exists in node '6fb0f6'. Skipping!
# Property 'keyphrases' already exists in node '40f05c'. Skipping!
# Applying KeyphrasesExtractor:  61%|██████    | 410/675 [02:35<02:16,  1.94it/s]Property 'keyphrases' already exists in node 'd3bcba'. Skipping!
# Applying KeyphrasesExtractor:  61%|██████    | 411/675 [02:36<02:34,  1.71it/s]Property 'keyphrases' already exists in node 'd433aa'. Skipping!
# Applying KeyphrasesExtractor:  61%|██████    | 412/675 [02:37<02:46,  1.58it/s]Property 'keyphrases' already exists in node '7811a9'. Skipping!
# Applying KeyphrasesExtractor:  61%|██████    | 413/675 [02:37<02:31,  1.73it/s]Property 'keyphrases' already exists in node '2fe3b5'. Skipping!
# Applying KeyphrasesExtractor:  61%|██████▏   | 414/675 [02:37<01:57,  2.21it/s]Property 'keyphrases' already exists in node '7ac0e8'. Skipping!
# Property 'keyphrases' already exists in node 'e70362'. Skipping!
# Applying KeyphrasesExtractor:  62%|██████▏   | 416/675 [02:37<01:13,  3.50it/s]Property 'keyphrases' already exists in node 'fcd073'. Skipping!
# Applying KeyphrasesExtractor:  62%|██████▏   | 417/675 [02:38<01:31,  2.81it/s]Property 'keyphrases' already exists in node '30e16b'. Skipping!
# Applying KeyphrasesExtractor:  62%|██████▏   | 418/675 [02:38<01:40,  2.55it/s]Property 'keyphrases' already exists in node '363214'. Skipping!
# Applying KeyphrasesExtractor:  62%|██████▏   | 419/675 [02:41<04:18,  1.01s/it]Property 'keyphrases' already exists in node 'bd95ef'. Skipping!
# Applying KeyphrasesExtractor:  62%|██████▏   | 420/675 [02:42<04:14,  1.00it/s]Property 'keyphrases' already exists in node '07ae34'. Skipping!
# Property 'keyphrases' already exists in node 'abeb16'. Skipping!
# Property 'keyphrases' already exists in node '2785ae'. Skipping!
# Applying KeyphrasesExtractor:  63%|██████▎   | 423/675 [02:43<02:30,  1.68it/s]Property 'keyphrases' already exists in node '2cafda'. Skipping!
# Property 'keyphrases' already exists in node '88edaf'. Skipping!
# Applying KeyphrasesExtractor:  63%|██████▎   | 425/675 [02:43<01:53,  2.21it/s]Property 'keyphrases' already exists in node '676267'. Skipping!
# Applying KeyphrasesExtractor:  63%|██████▎   | 426/675 [02:44<01:43,  2.41it/s]Property 'keyphrases' already exists in node 'd2a0df'. Skipping!
# Applying KeyphrasesExtractor:  63%|██████▎   | 427/675 [02:44<01:55,  2.14it/s]Property 'keyphrases' already exists in node '637366'. Skipping!
# Applying KeyphrasesExtractor:  63%|██████▎   | 428/675 [02:45<02:03,  2.00it/s]Property 'keyphrases' already exists in node '395760'. Skipping!
# Property 'keyphrases' already exists in node '69bcd8'. Skipping!
# Property 'keyphrases' already exists in node 'b1cc6d'. Skipping!
# Applying KeyphrasesExtractor:  64%|██████▍   | 431/675 [02:45<01:18,  3.12it/s]Property 'keyphrases' already exists in node '553d29'. Skipping!
# Applying KeyphrasesExtractor:  64%|██████▍   | 432/675 [02:46<01:18,  3.10it/s]Property 'keyphrases' already exists in node '26ebe2'. Skipping!
# Property 'keyphrases' already exists in node 'dd9498'. Skipping!
# Applying KeyphrasesExtractor:  64%|██████▍   | 434/675 [02:46<01:02,  3.86it/s]Property 'keyphrases' already exists in node 'ee4c5f'. Skipping!
# Applying KeyphrasesExtractor:  64%|██████▍   | 435/675 [02:47<01:48,  2.22it/s]Property 'keyphrases' already exists in node '1e65a6'. Skipping!
# Property 'keyphrases' already exists in node 'c6be30'. Skipping!
# Applying KeyphrasesExtractor:  65%|██████▍   | 437/675 [02:48<01:27,  2.73it/s]Property 'keyphrases' already exists in node '29be5a'. Skipping!
# Property 'keyphrases' already exists in node '44a256'. Skipping!
# Property 'keyphrases' already exists in node '7036a7'. Skipping!
# Applying KeyphrasesExtractor:  65%|██████▌   | 440/675 [02:48<00:52,  4.48it/s]Property 'keyphrases' already exists in node '0d8564'. Skipping!
# Property 'keyphrases' already exists in node 'c2489c'. Skipping!
# Applying KeyphrasesExtractor:  65%|██████▌   | 442/675 [02:49<01:18,  2.96it/s]Property 'keyphrases' already exists in node '0e9a08'. Skipping!
# Applying KeyphrasesExtractor:  66%|██████▌   | 443/675 [02:50<01:48,  2.13it/s]Property 'keyphrases' already exists in node '4e5596'. Skipping!
# Property 'keyphrases' already exists in node 'eb58f7'. Skipping!
# Applying KeyphrasesExtractor:  66%|██████▌   | 445/675 [02:51<01:36,  2.39it/s]Property 'keyphrases' already exists in node '2ad646'. Skipping!
# Applying KeyphrasesExtractor:  66%|██████▌   | 446/675 [02:51<01:22,  2.78it/s]Property 'keyphrases' already exists in node 'e11228'. Skipping!
# Applying KeyphrasesExtractor:  66%|██████▌   | 447/675 [02:51<01:09,  3.27it/s]Property 'keyphrases' already exists in node 'bde5d7'. Skipping!
# Applying KeyphrasesExtractor:  66%|██████▋   | 448/675 [02:51<01:03,  3.60it/s]Property 'keyphrases' already exists in node '75c25e'. Skipping!
# Property 'keyphrases' already exists in node 'd42246'. Skipping!
# Applying KeyphrasesExtractor:  67%|██████▋   | 450/675 [02:51<00:47,  4.75it/s]Property 'keyphrases' already exists in node '46cb59'. Skipping!
# Property 'keyphrases' already exists in node '4811e6'. Skipping!
# Applying KeyphrasesExtractor:  67%|██████▋   | 452/675 [02:51<00:36,  6.10it/s]Property 'keyphrases' already exists in node 'fa6140'. Skipping!
# Applying KeyphrasesExtractor:  67%|██████▋   | 454/675 [02:53<01:55,  1.92it/s]Property 'keyphrases' already exists in node '70b7b6'. Skipping!
# Applying KeyphrasesExtractor:  67%|██████▋   | 455/675 [02:54<01:42,  2.15it/s]Property 'keyphrases' already exists in node 'fd4c09'. Skipping!
# Applying KeyphrasesExtractor:  68%|██████▊   | 456/675 [02:54<01:30,  2.41it/s]Property 'keyphrases' already exists in node '91346c'. Skipping!
# Applying KeyphrasesExtractor:  68%|██████▊   | 457/675 [02:54<01:20,  2.72it/s]Property 'keyphrases' already exists in node 'b5b50c'. Skipping!
# Property 'keyphrases' already exists in node '7a3fc8'. Skipping!
# Applying KeyphrasesExtractor:  68%|██████▊   | 459/675 [02:55<01:11,  3.01it/s]Property 'keyphrases' already exists in node 'bd5281'. Skipping!
# Applying KeyphrasesExtractor:  68%|██████▊   | 460/675 [02:55<01:07,  3.17it/s]Property 'keyphrases' already exists in node '007588'. Skipping!
# Applying KeyphrasesExtractor:  68%|██████▊   | 461/675 [02:55<00:58,  3.67it/s]Property 'keyphrases' already exists in node '0452ec'. Skipping!
# Applying KeyphrasesExtractor:  69%|██████▊   | 463/675 [02:56<01:11,  2.96it/s]Property 'keyphrases' already exists in node '456ea8'. Skipping!
# Property 'keyphrases' already exists in node '5c40de'. Skipping!
# Applying KeyphrasesExtractor:  69%|██████▉   | 465/675 [02:56<00:50,  4.16it/s]Property 'keyphrases' already exists in node 'bfbea8'. Skipping!
# Applying KeyphrasesExtractor:  69%|██████▉   | 466/675 [02:57<01:00,  3.45it/s]Property 'keyphrases' already exists in node '893fb0'. Skipping!
# Applying KeyphrasesExtractor:  69%|██████▉   | 467/675 [02:57<01:05,  3.18it/s]Property 'keyphrases' already exists in node 'd0cec0'. Skipping!
# Applying KeyphrasesExtractor:  69%|██████▉   | 468/675 [02:57<00:58,  3.51it/s]Property 'keyphrases' already exists in node '6a3ca2'. Skipping!
# Applying KeyphrasesExtractor:  70%|██████▉   | 470/675 [02:58<00:54,  3.78it/s]Property 'keyphrases' already exists in node 'efd38a'. Skipping!
# Property 'keyphrases' already exists in node '04eb95'. Skipping!
# Applying KeyphrasesExtractor:  70%|██████▉   | 472/675 [02:59<01:14,  2.72it/s]Property 'keyphrases' already exists in node 'b17105'. Skipping!
# Property 'keyphrases' already exists in node 'f41870'. Skipping!
# Applying KeyphrasesExtractor:  70%|███████   | 473/675 [02:59<01:08,  2.97it/s]Property 'keyphrases' already exists in node 'da42c1'. Skipping!
# Property 'keyphrases' already exists in node '14b841'. Skipping!
# Applying KeyphrasesExtractor:  71%|███████   | 476/675 [03:00<00:58,  3.40it/s]Property 'keyphrases' already exists in node '3b370b'. Skipping!
# Property 'keyphrases' already exists in node 'd569a8'. Skipping!
# Applying KeyphrasesExtractor:  71%|███████   | 478/675 [03:00<00:46,  4.27it/s]Property 'keyphrases' already exists in node '57daa2'. Skipping!
# Applying KeyphrasesExtractor:  71%|███████   | 479/675 [03:01<01:08,  2.85it/s]Property 'keyphrases' already exists in node '8fdfb4'. Skipping!
# Applying KeyphrasesExtractor:  71%|███████▏  | 481/675 [03:02<01:23,  2.34it/s]Property 'keyphrases' already exists in node '96f6f5'. Skipping!
# Applying KeyphrasesExtractor:  71%|███████▏  | 482/675 [03:03<01:35,  2.01it/s]Property 'keyphrases' already exists in node '37a8f4'. Skipping!
# Applying KeyphrasesExtractor:  72%|███████▏  | 483/675 [03:03<01:51,  1.72it/s]Property 'keyphrases' already exists in node 'd5627b'. Skipping!
# Applying KeyphrasesExtractor:  72%|███████▏  | 484/675 [03:04<01:35,  1.99it/s]Property 'keyphrases' already exists in node 'e02240'. Skipping!
# Applying KeyphrasesExtractor:  72%|███████▏  | 485/675 [03:04<01:25,  2.23it/s]Property 'keyphrases' already exists in node '59c584'. Skipping!
# Applying KeyphrasesExtractor:  72%|███████▏  | 486/675 [03:05<02:08,  1.47it/s]Property 'keyphrases' already exists in node '8f699e'. Skipping!
# Property 'keyphrases' already exists in node '99ef23'. Skipping!
# Property 'keyphrases' already exists in node '548b2c'. Skipping!
# Applying KeyphrasesExtractor:  72%|███████▏  | 489/675 [03:06<01:21,  2.27it/s]Property 'keyphrases' already exists in node 'b31899'. Skipping!
# Property 'keyphrases' already exists in node '4385c8'. Skipping!
# Applying KeyphrasesExtractor:  73%|███████▎  | 491/675 [03:07<01:20,  2.29it/s]Property 'keyphrases' already exists in node '5677c8'. Skipping!
# Applying KeyphrasesExtractor:  73%|███████▎  | 492/675 [03:07<01:08,  2.68it/s]Property 'keyphrases' already exists in node 'adbf6b'. Skipping!
# Applying KeyphrasesExtractor:  73%|███████▎  | 493/675 [03:08<01:23,  2.19it/s]Property 'keyphrases' already exists in node 'a67fd6'. Skipping!
# Applying KeyphrasesExtractor:  73%|███████▎  | 494/675 [03:08<01:32,  1.96it/s]Property 'keyphrases' already exists in node '73acdd'. Skipping!
# Applying KeyphrasesExtractor:  73%|███████▎  | 495/675 [03:10<02:29,  1.20it/s]Property 'keyphrases' already exists in node 'a841d4'. Skipping!
# Applying KeyphrasesExtractor:  73%|███████▎  | 496/675 [03:11<02:12,  1.35it/s]Property 'keyphrases' already exists in node 'c925ad'. Skipping!
# Property 'keyphrases' already exists in node 'c9fa7e'. Skipping!
# Applying KeyphrasesExtractor:  74%|███████▍  | 498/675 [03:11<01:22,  2.14it/s]Property 'keyphrases' already exists in node '0a2595'. Skipping!
# Applying KeyphrasesExtractor:  74%|███████▍  | 499/675 [03:11<01:21,  2.16it/s]Property 'keyphrases' already exists in node '13afb4'. Skipping!
# Applying KeyphrasesExtractor:  74%|███████▍  | 500/675 [03:12<01:29,  1.95it/s]Property 'keyphrases' already exists in node '8a65d1'. Skipping!
# Applying KeyphrasesExtractor:  74%|███████▍  | 501/675 [03:12<01:25,  2.03it/s]Property 'keyphrases' already exists in node '498b1b'. Skipping!
# Applying KeyphrasesExtractor:  74%|███████▍  | 502/675 [03:13<01:16,  2.25it/s]Property 'keyphrases' already exists in node '0d2316'. Skipping!
# Applying KeyphrasesExtractor:  75%|███████▍  | 503/675 [03:13<01:24,  2.04it/s]Property 'keyphrases' already exists in node '8465f7'. Skipping!
# Applying KeyphrasesExtractor:  75%|███████▍  | 504/675 [03:14<01:14,  2.29it/s]Property 'keyphrases' already exists in node 'ee9ae9'. Skipping!
# Property 'keyphrases' already exists in node '5a64f1'. Skipping!
# Applying KeyphrasesExtractor:  75%|███████▍  | 506/675 [03:14<01:00,  2.79it/s]Property 'keyphrases' already exists in node 'c455f1'. Skipping!
# Applying KeyphrasesExtractor:  75%|███████▌  | 507/675 [03:14<00:57,  2.93it/s]Property 'keyphrases' already exists in node '70b528'. Skipping!
# Applying KeyphrasesExtractor:  75%|███████▌  | 508/675 [03:15<00:49,  3.37it/s]Property 'keyphrases' already exists in node '81b4a6'. Skipping!
# Applying KeyphrasesExtractor:  75%|███████▌  | 509/675 [03:15<00:48,  3.46it/s]Property 'keyphrases' already exists in node '012206'. Skipping!
# Property 'keyphrases' already exists in node '616ab1'. Skipping!
# Applying KeyphrasesExtractor:  76%|███████▌  | 511/675 [03:15<00:32,  4.99it/s]Property 'keyphrases' already exists in node '633ead'. Skipping!
# Applying KeyphrasesExtractor:  76%|███████▌  | 512/675 [03:15<00:30,  5.37it/s]Property 'keyphrases' already exists in node '96e69f'. Skipping!
# Property 'keyphrases' already exists in node '1deb8c'. Skipping!
# Applying KeyphrasesExtractor:  76%|███████▌  | 514/675 [03:16<00:47,  3.38it/s]Property 'keyphrases' already exists in node '55dca0'. Skipping!
# Property 'keyphrases' already exists in node '12ab3c'. Skipping!
# Applying KeyphrasesExtractor:  76%|███████▋  | 516/675 [03:17<01:00,  2.64it/s]Property 'keyphrases' already exists in node 'bbd6d8'. Skipping!
# Property 'keyphrases' already exists in node 'aa4d7f'. Skipping!
# Applying KeyphrasesExtractor:  77%|███████▋  | 518/675 [03:17<00:46,  3.41it/s]Property 'keyphrases' already exists in node 'c7b597'. Skipping!
# Applying KeyphrasesExtractor:  77%|███████▋  | 519/675 [03:18<00:49,  3.16it/s]Property 'keyphrases' already exists in node '417dd7'. Skipping!
# Applying KeyphrasesExtractor:  77%|███████▋  | 520/675 [03:18<00:47,  3.25it/s]Property 'keyphrases' already exists in node '5ec956'. Skipping!
# Applying KeyphrasesExtractor:  77%|███████▋  | 521/675 [03:18<00:40,  3.83it/s]Property 'keyphrases' already exists in node '8313f8'. Skipping!
# Applying KeyphrasesExtractor:  77%|███████▋  | 522/675 [03:19<00:48,  3.17it/s]Property 'keyphrases' already exists in node '8862d4'. Skipping!
# Applying KeyphrasesExtractor:  77%|███████▋  | 523/675 [03:19<00:51,  2.97it/s]Property 'keyphrases' already exists in node '76df72'. Skipping!
# Applying KeyphrasesExtractor:  78%|███████▊  | 524/675 [03:19<00:51,  2.95it/s]Property 'keyphrases' already exists in node 'c52c2d'. Skipping!
# Applying KeyphrasesExtractor:  78%|███████▊  | 525/675 [03:20<01:06,  2.26it/s]Property 'keyphrases' already exists in node '4a16f7'. Skipping!
# Property 'keyphrases' already exists in node '870637'. Skipping!
# Applying KeyphrasesExtractor:  78%|███████▊  | 527/675 [03:20<00:42,  3.49it/s]Property 'keyphrases' already exists in node '90f689'. Skipping!
# Applying KeyphrasesExtractor:  78%|███████▊  | 528/675 [03:20<00:37,  3.90it/s]Property 'keyphrases' already exists in node 'bc1110'. Skipping!
# Applying KeyphrasesExtractor:  78%|███████▊  | 529/675 [03:21<00:33,  4.41it/s]Property 'keyphrases' already exists in node '112fdc'. Skipping!
# Applying KeyphrasesExtractor:  79%|███████▊  | 530/675 [03:21<00:49,  2.92it/s]Property 'keyphrases' already exists in node '4df22b'. Skipping!
# Property 'keyphrases' already exists in node '19ef9c'. Skipping!
# Applying KeyphrasesExtractor:  79%|███████▉  | 532/675 [03:22<00:50,  2.83it/s]Property 'keyphrases' already exists in node '049c66'. Skipping!
# Property 'keyphrases' already exists in node 'a9a763'. Skipping!
# Applying KeyphrasesExtractor:  79%|███████▉  | 534/675 [03:23<00:48,  2.88it/s]Property 'keyphrases' already exists in node 'd89802'. Skipping!
# Applying KeyphrasesExtractor:  79%|███████▉  | 535/675 [03:23<00:43,  3.22it/s]Property 'keyphrases' already exists in node '506209'. Skipping!
# Applying KeyphrasesExtractor:  79%|███████▉  | 536/675 [03:23<00:49,  2.79it/s]Property 'keyphrases' already exists in node 'a1c220'. Skipping!
# Applying KeyphrasesExtractor:  80%|███████▉  | 537/675 [03:24<00:48,  2.82it/s]Property 'keyphrases' already exists in node '945cd0'. Skipping!
# Applying KeyphrasesExtractor:  80%|███████▉  | 538/675 [03:24<00:47,  2.87it/s]Property 'keyphrases' already exists in node 'f9c781'. Skipping!
# Applying KeyphrasesExtractor:  80%|███████▉  | 539/675 [03:24<00:44,  3.05it/s]Property 'keyphrases' already exists in node 'e6cf01'. Skipping!
# Applying KeyphrasesExtractor:  80%|████████  | 540/675 [03:25<00:45,  2.97it/s]Property 'keyphrases' already exists in node '4663cb'. Skipping!
# Applying KeyphrasesExtractor:  80%|████████  | 541/675 [03:25<00:50,  2.63it/s]Property 'keyphrases' already exists in node 'c4a70a'. Skipping!
# Applying KeyphrasesExtractor:  80%|████████  | 542/675 [03:25<00:46,  2.87it/s]Property 'keyphrases' already exists in node '02f987'. Skipping!
# Applying KeyphrasesExtractor:  80%|████████  | 543/675 [03:26<00:38,  3.43it/s]Property 'keyphrases' already exists in node '50b56e'. Skipping!
# Applying KeyphrasesExtractor:  81%|████████  | 544/675 [03:26<00:37,  3.45it/s]Property 'keyphrases' already exists in node '986130'. Skipping!
# Applying KeyphrasesExtractor:  81%|████████  | 545/675 [03:26<00:41,  3.14it/s]Property 'keyphrases' already exists in node '604426'. Skipping!
# Applying KeyphrasesExtractor:  81%|████████  | 546/675 [03:27<00:38,  3.32it/s]Property 'keyphrases' already exists in node '55fc5b'. Skipping!
# Property 'keyphrases' already exists in node 'd76db0'. Skipping!
# Applying KeyphrasesExtractor:  81%|████████  | 548/675 [03:27<00:48,  2.64it/s]Property 'keyphrases' already exists in node '94832b'. Skipping!
# Applying KeyphrasesExtractor:  81%|████████▏ | 549/675 [03:28<00:39,  3.23it/s]Property 'keyphrases' already exists in node '745b72'. Skipping!
# Applying KeyphrasesExtractor:  81%|████████▏ | 550/675 [03:28<00:39,  3.17it/s]Property 'keyphrases' already exists in node 'd31576'. Skipping!
# Applying KeyphrasesExtractor:  82%|████████▏ | 551/675 [03:28<00:36,  3.44it/s]Property 'keyphrases' already exists in node 'fcde60'. Skipping!
# Property 'keyphrases' already exists in node '85185d'. Skipping!
# Applying KeyphrasesExtractor:  82%|████████▏ | 553/675 [03:28<00:24,  5.07it/s]Property 'keyphrases' already exists in node 'ca410f'. Skipping!
# Applying KeyphrasesExtractor:  82%|████████▏ | 554/675 [03:29<00:31,  3.86it/s]Property 'keyphrases' already exists in node 'aeaf2e'. Skipping!
# Applying KeyphrasesExtractor:  82%|████████▏ | 555/675 [03:29<00:31,  3.75it/s]Property 'keyphrases' already exists in node 'b60497'. Skipping!
# Applying KeyphrasesExtractor:  82%|████████▏ | 556/675 [03:29<00:33,  3.59it/s]Property 'keyphrases' already exists in node '476590'. Skipping!
# Applying KeyphrasesExtractor:  83%|████████▎ | 557/675 [03:31<01:02,  1.88it/s]Property 'keyphrases' already exists in node 'aee72e'. Skipping!
# Applying KeyphrasesExtractor:  83%|████████▎ | 558/675 [03:31<00:57,  2.02it/s]Property 'keyphrases' already exists in node '7a6a40'. Skipping!
# Applying KeyphrasesExtractor:  83%|████████▎ | 559/675 [03:31<00:45,  2.53it/s]Property 'keyphrases' already exists in node 'b5add4'. Skipping!
# Property 'keyphrases' already exists in node '4d404b'. Skipping!
# Property 'keyphrases' already exists in node 'afa603'. Skipping!
# Applying KeyphrasesExtractor:  83%|████████▎ | 561/675 [03:33<01:02,  1.83it/s]Property 'keyphrases' already exists in node '6a5825'. Skipping!
# Applying KeyphrasesExtractor:  84%|████████▎ | 564/675 [03:33<00:35,  3.14it/s]Property 'keyphrases' already exists in node 'ccc96a'. Skipping!
# Applying KeyphrasesExtractor:  84%|████████▎ | 565/675 [03:35<01:08,  1.62it/s]Property 'keyphrases' already exists in node 'e79a5e'. Skipping!
# Applying KeyphrasesExtractor:  84%|████████▍ | 566/675 [03:37<01:39,  1.09it/s]Property 'keyphrases' already exists in node '1107b8'. Skipping!
# Applying KeyphrasesExtractor:  84%|████████▍ | 568/675 [03:38<01:24,  1.27it/s]Property 'keyphrases' already exists in node '90aa88'. Skipping!
# Applying KeyphrasesExtractor:  84%|████████▍ | 569/675 [03:38<01:10,  1.51it/s]Property 'keyphrases' already exists in node '949105'. Skipping!
# Applying KeyphrasesExtractor:  84%|████████▍ | 570/675 [03:38<00:59,  1.77it/s]Property 'keyphrases' already exists in node '287ebb'. Skipping!
# Property 'keyphrases' already exists in node 'b4caa6'. Skipping!
# Applying KeyphrasesExtractor:  85%|████████▍ | 572/675 [03:39<00:40,  2.57it/s]Property 'keyphrases' already exists in node 'be013f'. Skipping!
# Applying KeyphrasesExtractor:  85%|████████▍ | 573/675 [03:39<00:33,  3.03it/s]Property 'keyphrases' already exists in node 'ff669c'. Skipping!
# Applying KeyphrasesExtractor:  85%|████████▌ | 574/675 [03:39<00:28,  3.56it/s]Property 'keyphrases' already exists in node '0c9219'. Skipping!
# Applying KeyphrasesExtractor:  85%|████████▌ | 575/675 [03:39<00:32,  3.07it/s]Property 'keyphrases' already exists in node 'e70e5f'. Skipping!
# Applying KeyphrasesExtractor:  85%|████████▌ | 576/675 [03:40<00:28,  3.52it/s]Property 'keyphrases' already exists in node '8f512d'. Skipping!
# Property 'keyphrases' already exists in node '71c2da'. Skipping!
# Applying KeyphrasesExtractor:  86%|████████▌ | 578/675 [03:40<00:33,  2.90it/s]Property 'keyphrases' already exists in node '0b6c5a'. Skipping!
# Property 'keyphrases' already exists in node '6eee5b'. Skipping!
# Property 'keyphrases' already exists in node '6eac55'. Skipping!
# Applying KeyphrasesExtractor:  86%|████████▌ | 581/675 [03:41<00:20,  4.50it/s]Property 'keyphrases' already exists in node '33167a'. Skipping!
# Applying KeyphrasesExtractor:  86%|████████▌ | 582/675 [03:41<00:21,  4.31it/s]Property 'keyphrases' already exists in node 'a2bee6'. Skipping!
# Applying KeyphrasesExtractor:  86%|████████▋ | 583/675 [03:42<00:29,  3.12it/s]Property 'keyphrases' already exists in node 'dbd0b7'. Skipping!
# Applying KeyphrasesExtractor:  87%|████████▋ | 584/675 [03:42<00:30,  2.94it/s]Property 'keyphrases' already exists in node 'ab1532'. Skipping!
# Property 'keyphrases' already exists in node '424cfe'. Skipping!
# Applying KeyphrasesExtractor:  87%|████████▋ | 586/675 [03:42<00:24,  3.68it/s]Property 'keyphrases' already exists in node '3ab1c3'. Skipping!
# Applying KeyphrasesExtractor:  87%|████████▋ | 587/675 [03:43<00:36,  2.41it/s]Property 'keyphrases' already exists in node '934663'. Skipping!
# Applying KeyphrasesExtractor:  87%|████████▋ | 588/675 [03:44<00:35,  2.44it/s]Property 'keyphrases' already exists in node '697ef8'. Skipping!
# Property 'keyphrases' already exists in node '764a4b'. Skipping!
# Applying KeyphrasesExtractor:  87%|████████▋ | 590/675 [03:44<00:23,  3.59it/s]Property 'keyphrases' already exists in node 'b0c9aa'. Skipping!
# Applying KeyphrasesExtractor:  88%|████████▊ | 591/675 [03:44<00:20,  4.19it/s]Property 'keyphrases' already exists in node '03b234'. Skipping!
# Applying KeyphrasesExtractor:  88%|████████▊ | 592/675 [03:45<00:27,  3.06it/s]Property 'keyphrases' already exists in node '6b0239'. Skipping!
# Applying KeyphrasesExtractor:  88%|████████▊ | 593/675 [03:45<00:23,  3.45it/s]Property 'keyphrases' already exists in node 'b11d69'. Skipping!
# Applying KeyphrasesExtractor:  88%|████████▊ | 594/675 [03:45<00:19,  4.06it/s]Property 'keyphrases' already exists in node 'a7977e'. Skipping!
# Applying KeyphrasesExtractor:  88%|████████▊ | 595/675 [03:45<00:17,  4.47it/s]Property 'keyphrases' already exists in node 'a1b81b'. Skipping!
# Applying KeyphrasesExtractor:  88%|████████▊ | 596/675 [03:45<00:19,  4.02it/s]Property 'keyphrases' already exists in node '545329'. Skipping!
# Applying KeyphrasesExtractor:  88%|████████▊ | 597/675 [03:46<00:19,  3.95it/s]Property 'keyphrases' already exists in node 'b6b938'. Skipping!
# Applying KeyphrasesExtractor:  89%|████████▊ | 598/675 [03:47<00:34,  2.24it/s]Property 'keyphrases' already exists in node '820157'. Skipping!
# Applying KeyphrasesExtractor:  89%|████████▊ | 599/675 [03:47<00:29,  2.54it/s]Property 'keyphrases' already exists in node 'a245f4'. Skipping!
# Applying KeyphrasesExtractor:  89%|████████▉ | 600/675 [03:47<00:25,  2.98it/s]Property 'keyphrases' already exists in node '00e817'. Skipping!
# Applying KeyphrasesExtractor:  89%|████████▉ | 601/675 [03:47<00:21,  3.49it/s]Property 'keyphrases' already exists in node '7db000'. Skipping!
# Applying KeyphrasesExtractor:  89%|████████▉ | 602/675 [03:47<00:18,  3.88it/s]Property 'keyphrases' already exists in node '6ce718'. Skipping!
# Applying KeyphrasesExtractor:  89%|████████▉ | 603/675 [03:48<00:29,  2.41it/s]Property 'keyphrases' already exists in node '60d79e'. Skipping!
# Property 'keyphrases' already exists in node '60126e'. Skipping!
# Applying KeyphrasesExtractor:  90%|████████▉ | 605/675 [03:48<00:17,  3.95it/s]Property 'keyphrases' already exists in node '508674'. Skipping!
# Applying KeyphrasesExtractor:  90%|████████▉ | 606/675 [03:49<00:28,  2.45it/s]Property 'keyphrases' already exists in node '998d97'. Skipping!
# Applying KeyphrasesExtractor:  90%|████████▉ | 607/675 [03:50<00:35,  1.92it/s]Property 'keyphrases' already exists in node '4f16e4'. Skipping!
# Applying KeyphrasesExtractor:  90%|█████████ | 609/675 [03:50<00:23,  2.81it/s]Property 'keyphrases' already exists in node 'e1e336'. Skipping!
# Property 'keyphrases' already exists in node 'd3f81d'. Skipping!
# Applying KeyphrasesExtractor:  91%|█████████ | 611/675 [03:51<00:17,  3.67it/s]Property 'keyphrases' already exists in node '262b40'. Skipping!
# Applying KeyphrasesExtractor:  91%|█████████ | 612/675 [03:51<00:19,  3.25it/s]Property 'keyphrases' already exists in node 'a5f4b1'. Skipping!
# Property 'keyphrases' already exists in node '6b8068'. Skipping!
# Applying KeyphrasesExtractor:  91%|█████████ | 614/675 [03:51<00:12,  4.75it/s]Property 'keyphrases' already exists in node '8986b2'. Skipping!
# Applying KeyphrasesExtractor:  91%|█████████▏| 616/675 [03:51<00:11,  4.96it/s]Property 'keyphrases' already exists in node '2bdc8a'. Skipping!
# Property 'keyphrases' already exists in node '27dfb0'. Skipping!
# Property 'keyphrases' already exists in node '977d6b'. Skipping!
# Applying KeyphrasesExtractor:  92%|█████████▏| 619/675 [03:52<00:11,  4.73it/s]Property 'keyphrases' already exists in node 'b6db25'. Skipping!
# Property 'keyphrases' already exists in node 'f1fcbd'. Skipping!
# Applying KeyphrasesExtractor:  92%|█████████▏| 621/675 [03:53<00:17,  3.05it/s]Property 'keyphrases' already exists in node 'f5721b'. Skipping!
# Applying KeyphrasesExtractor:  92%|█████████▏| 622/675 [03:54<00:20,  2.59it/s]Property 'keyphrases' already exists in node '97b006'. Skipping!
# Applying KeyphrasesExtractor:  92%|█████████▏| 623/675 [03:55<00:24,  2.15it/s]Property 'keyphrases' already exists in node 'e46c97'. Skipping!
# Applying KeyphrasesExtractor:  92%|█████████▏| 624/675 [03:55<00:23,  2.13it/s]Property 'keyphrases' already exists in node 'f79e6a'. Skipping!
# Property 'keyphrases' already exists in node '89b9b9'. Skipping!
# Applying KeyphrasesExtractor:  93%|█████████▎| 626/675 [03:55<00:15,  3.18it/s]Property 'keyphrases' already exists in node '4265d7'. Skipping!
# Applying KeyphrasesExtractor:  93%|█████████▎| 627/675 [03:56<00:14,  3.38it/s]Property 'keyphrases' already exists in node 'b80357'. Skipping!
# Applying KeyphrasesExtractor:  93%|█████████▎| 628/675 [03:56<00:15,  2.97it/s]Property 'keyphrases' already exists in node '7b6864'. Skipping!
# Applying KeyphrasesExtractor:  93%|█████████▎| 629/675 [03:56<00:15,  2.96it/s]Property 'keyphrases' already exists in node '1ff62f'. Skipping!
# Property 'keyphrases' already exists in node 'c58e67'. Skipping!
# Applying KeyphrasesExtractor:  94%|█████████▎| 632/675 [03:57<00:11,  3.59it/s]Property 'keyphrases' already exists in node '3a1b55'. Skipping!
# Applying KeyphrasesExtractor:  94%|█████████▍| 633/675 [03:58<00:15,  2.71it/s]Property 'keyphrases' already exists in node '987a16'. Skipping!
# Applying KeyphrasesExtractor:  94%|█████████▍| 634/675 [03:58<00:12,  3.27it/s]Property 'keyphrases' already exists in node '218b0b'. Skipping!
# Applying KeyphrasesExtractor:  94%|█████████▍| 635/675 [03:59<00:18,  2.19it/s]Property 'keyphrases' already exists in node 'd33ab1'. Skipping!
# Applying KeyphrasesExtractor:  94%|█████████▍| 636/675 [03:59<00:19,  2.04it/s]Property 'keyphrases' already exists in node 'a495fd'. Skipping!
# Applying KeyphrasesExtractor:  94%|█████████▍| 637/675 [04:01<00:30,  1.27it/s]Property 'keyphrases' already exists in node 'b5e200'. Skipping!
# Applying KeyphrasesExtractor:  95%|█████████▍| 638/675 [04:02<00:29,  1.27it/s]Property 'keyphrases' already exists in node '8a5e1f'. Skipping!
# Applying KeyphrasesExtractor:  95%|█████████▍| 639/675 [04:02<00:24,  1.46it/s]Property 'keyphrases' already exists in node '02e71e'. Skipping!
# Applying KeyphrasesExtractor:  95%|█████████▍| 640/675 [04:03<00:27,  1.25it/s]Property 'keyphrases' already exists in node '52d5c0'. Skipping!
# Applying KeyphrasesExtractor:  95%|█████████▍| 641/675 [04:03<00:20,  1.64it/s]Property 'keyphrases' already exists in node 'f68a35'. Skipping!
# Applying KeyphrasesExtractor:  95%|█████████▌| 642/675 [04:04<00:19,  1.69it/s]Property 'keyphrases' already exists in node 'f422b1'. Skipping!
# Applying KeyphrasesExtractor:  95%|█████████▌| 643/675 [04:04<00:15,  2.07it/s]Property 'keyphrases' already exists in node '6ab919'. Skipping!
# Applying KeyphrasesExtractor:  95%|█████████▌| 644/675 [04:04<00:12,  2.57it/s]Property 'keyphrases' already exists in node 'b43478'. Skipping!
# Applying KeyphrasesExtractor:  96%|█████████▌| 645/675 [04:05<00:13,  2.25it/s]Property 'keyphrases' already exists in node '6c34cf'. Skipping!
# Property 'keyphrases' already exists in node '80f5ae'. Skipping!
# Applying KeyphrasesExtractor:  96%|█████████▌| 647/675 [04:05<00:10,  2.77it/s]Property 'keyphrases' already exists in node 'ecad09'. Skipping!
# Property 'keyphrases' already exists in node 'd16aa5'. Skipping!
# Applying KeyphrasesExtractor:  96%|█████████▌| 649/675 [04:06<00:07,  3.49it/s]Property 'keyphrases' already exists in node '2a03a1'. Skipping!
# Property 'keyphrases' already exists in node '5e2b3d'. Skipping!
# Applying KeyphrasesExtractor:  96%|█████████▋| 651/675 [04:06<00:06,  3.82it/s]Property 'keyphrases' already exists in node '40b15b'. Skipping!
# Applying KeyphrasesExtractor:  97%|█████████▋| 652/675 [04:07<00:09,  2.44it/s]Property 'keyphrases' already exists in node '63cc0b'. Skipping!
# Applying KeyphrasesExtractor:  97%|█████████▋| 653/675 [04:08<00:10,  2.11it/s]Property 'keyphrases' already exists in node '35b5bb'. Skipping!
# Applying KeyphrasesExtractor:  97%|█████████▋| 654/675 [04:08<00:08,  2.61it/s]Property 'keyphrases' already exists in node '4bba2a'. Skipping!
# Property 'keyphrases' already exists in node '6ca172'. Skipping!
# Applying KeyphrasesExtractor:  97%|█████████▋| 656/675 [04:08<00:04,  4.02it/s]Property 'keyphrases' already exists in node 'c75b0b'. Skipping!
# Applying KeyphrasesExtractor:  97%|█████████▋| 657/675 [04:08<00:04,  4.02it/s]Property 'keyphrases' already exists in node '31a225'. Skipping!
# Applying KeyphrasesExtractor:  97%|█████████▋| 658/675 [04:08<00:03,  4.63it/s]Property 'keyphrases' already exists in node '49b0dd'. Skipping!
# Applying KeyphrasesExtractor:  98%|█████████▊| 659/675 [04:09<00:03,  4.25it/s]Property 'keyphrases' already exists in node '55704e'. Skipping!
# Applying KeyphrasesExtractor:  98%|█████████▊| 660/675 [04:09<00:03,  4.61it/s]Property 'keyphrases' already exists in node 'f223e4'. Skipping!
# Applying KeyphrasesExtractor:  98%|█████████▊| 661/675 [04:09<00:03,  3.66it/s]Property 'keyphrases' already exists in node 'a324d7'. Skipping!
# Applying KeyphrasesExtractor:  98%|█████████▊| 662/675 [04:09<00:03,  4.11it/s]Property 'keyphrases' already exists in node 'de3ad3'. Skipping!
# Property 'keyphrases' already exists in node '4acb9f'. Skipping!
# Applying KeyphrasesExtractor:  98%|█████████▊| 664/675 [04:09<00:01,  6.36it/s]Property 'keyphrases' already exists in node 'd027b8'. Skipping!
# Applying KeyphrasesExtractor:  99%|█████████▊| 665/675 [04:10<00:01,  5.12it/s]Property 'keyphrases' already exists in node '61e727'. Skipping!
# Applying KeyphrasesExtractor:  99%|█████████▊| 666/675 [04:10<00:01,  4.89it/s]Property 'keyphrases' already exists in node '672568'. Skipping!
# Applying KeyphrasesExtractor:  99%|█████████▉| 667/675 [04:10<00:01,  4.99it/s]Property 'keyphrases' already exists in node '50e4f6'. Skipping!
# Applying KeyphrasesExtractor:  99%|█████████▉| 668/675 [04:11<00:03,  2.17it/s]Property 'keyphrases' already exists in node '6a28d4'. Skipping!
# Property 'keyphrases' already exists in node '4d4390'. Skipping!
# Applying KeyphrasesExtractor:  99%|█████████▉| 669/675 [04:12<00:02,  2.50it/s]Property 'keyphrases' already exists in node '21709a'. Skipping!
# Property 'keyphrases' already exists in node 'bbfcc6'. Skipping!
# Applying KeyphrasesExtractor: 100%|█████████▉| 672/675 [04:12<00:00,  3.57it/s]Property 'keyphrases' already exists in node '837ddf'. Skipping!
# Applying KeyphrasesExtractor: 100%|█████████▉| 673/675 [04:13<00:00,  3.29it/s]Property 'keyphrases' already exists in node '27f8b8'. Skipping!
# Applying KeyphrasesExtractor: 100%|█████████▉| 674/675 [04:13<00:00,  2.36it/s]Property 'keyphrases' already exists in node 'fd118f'. Skipping!
# Knowledge graph now has 675 nodes after transforms.

# %%
scenarios = await query.generate_scenarios(
    n=scenario_num,
    knowledge_graph=kg,
    persona_list=personas,
    callbacks=None
)

pprint(scenarios)
# Out:
# [MultiHopScenario(
# nodes=2
# combinations=['spiking neural networks', 'spiking neuron networks']
# style=Poor grammar
# length=short
# persona=name='Prepared Computer Science Student' role_description='A university student learning about sustainable software engineering. Has a good general overview of topics, but intrested in the finer technical details.'),
#  MultiHopScenario(
# nodes=2
# combinations=['Government-developed software', 'government-developed OS software']
# style=Misspelled queries
# length=short
# persona=name='Professional Developer' role_description='A software developer in the industry looking to learn about green software practices to apply in their projects and convince management of their importance.'),
#  MultiHopScenario(
# nodes=2
# combinations=['data science', 'data centers']
# style=Misspelled queries
# length=long
# persona=name='Prepared Computer Science Student' role_description='A university student learning about sustainable software engineering. Has a good general overview of topics, but intrested in the finer technical details.'),
#  MultiHopScenario(
# nodes=2
# combinations=['reduce risk', 'Reduce Size']
# style=Poor grammar
# length=short
# persona=name='Prepared Computer Science Student' role_description='A university student learning about sustainable software engineering. Has a good general overview of topics, but intrested in the finer technical details.'),
#  MultiHopScenario(
# nodes=2
# combinations=['Neuromorphic computer/chip', 'neuromorphic computing']
# style=Web search like queries
# length=medium
# persona=name='Professional Developer' role_description='A software developer in the industry looking to learn about green software practices to apply in their projects and convince management of their importance.')]

# %%
results = await query.generate_sample(
    scenario=scenarios[-1]
)

pprint(results)
# Out:
# SingleTurnSample(user_input='What is the biological basis of neuromorphic computing, and how does it differ from conventional neural networks?', retrieved_contexts=None, reference_contexts=['<1-hop>\n\nNeuromorphic computing\nNeuromorphic computing is an approach to computing that is inspired by the structure and function of the human brain.\nA neuromorphic computer/chip is any device that uses physical artificial neurons to do computations.\nhttps://en.wikipedia.org/wiki/Neuromorphic_engineering, https://www.informationweek.com/software-services/what-you-need-to-know-about-neuromorphic-computing', '<2-hop>\n\nReading materials\nMain reading:\n- Section 1 and Section 3.1 of "Computing with spiking neuron networks." by Paugam-Moisy H, Bohte SM, in Handbook of natural computing (2012). \nhttps://homepages.cwi.nl/~sbohte/publication/paugam_moisy_bohte_SNNChapter.pdf\n- Maass W. Networks of spiking neurons: the third generation of neural network models. Neural networks. 1997. 10(9):1659-71. https://igi-web.tugraz.at/people/maass/psfiles/85a.pdf\n- Neuromorphic computing:\n- Based on biology: Zenke F, Bohté SM, Clopath C, Comşa IM, Göltz J, Maass W, Masquelier T, Naud R, Neftci EO, Petrovici MA, Scherr F. Visualizing a joint future of \nneuroscience and neuromorphic engineering. Neuron. 2021. 109(4):571-5. https://www.sciencedirect.com/science/article/pii/S089662732100009X\n- How to train modern spiking networks: Neftci EO, Mostafa H, Zenke F. Surrogate gradient learning in spiking neural networks: Bringing the power of gradient-based \noptimization to spiking neural networks. IEEE Signal Processing Magazine. 2019. 36(6):51-63. https://ieeexplore.ieee.org/abstract/document/8891809\n- Rate-based SNNs: Roy K, Jaiswal A, Panda P. Towards spike-based machine intelligence with neuromorphic computing. Nature. 2019. 575(7784):607-17. \nhttps://www.nature.com/articles/s41586-019-1677-2\nExtra reading:\n- Converging history of deep networks and biological systems: Sejnowski TJ. The unreasonable effectiveness of deep learning in artificial intelligence. Proceedings of the National \nAcademy of Sciences. 2020. 117(48):30033-8. https://www.pnas.org/doi/full/10.1073/pnas.1907373117\n- Also an important part of neuromorphic systems and vision → Event Cameras: Gallego G, Delbrück T, Orchard G, Bartolozzi C, Taba B, Censi A, Leutenegger S, Davison AJ, Conradt J, \nDaniilidis K, Scaramuzza D. Event-based vision: A survey. IEEE transactions on pattern analysis and machine intelligence. 2020. 44(1):154-80. \nhttps://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=9138762\nBasics of \'conventional\' neural networks:\n- Sections 4.1 to 4.4 from the book "Pattern Recognition" by Theodoridis and Koutroumbas.\n- Subsection 4.1.7 from the book "Pattern Recognition and Machine Learning" by Bishop.'], response=None, multi_responses=None, reference="Neuromorphic computing is based on the biological principles of the human brain, utilizing physical artificial neurons to perform computations. Unlike conventional neural networks, which rely on traditional computing architectures, neuromorphic systems are designed to mimic the brain's structure and function, enabling more efficient and biologically inspired processing.", rubrics=None)

# %% [markdown]
# ## Generate the multi-hop dataset based on SSE Course Slides
#
# You can modify the testset_size variable to change number of samples in testset.

# %%
testset_size = 50
testset = []
testset_counter = 0
while testset_counter < testset_size:
    for i in range(len(scenarios)):
        if testset_counter >= testset_size:
            break
        sample = await query.generate_sample(scenario=scenarios[i])
        testset_counter += 1
        for context in (sample.reference_contexts or [""]):  # Handle None case
            testset.append({
                "user_input": sample.user_input,
                "reference": sample.reference,
                "reference_contexts": context
            })

# Create DataFrame and save to CSV
df = pd.DataFrame(testset)
df.to_csv("sse_multihop_testset.csv", index=False)
